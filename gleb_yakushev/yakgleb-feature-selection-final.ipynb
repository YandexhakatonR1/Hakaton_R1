# %% [markdown]
# ## Изучение данных

# %%
#!pip install phik

# %%
import json
import pandas as pd
import numpy as np

from phik import resources
from phik.binning import bin_data
from phik.report import plot_correlation_matrix
from phik import report

import catboost as cb
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from catboost import CatBoostClassifier
from sklearn.utils import shuffle

from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression

# %%
f = open('features_types.json')
features_types = json.load(f)

# %%
data_features = pd.DataFrame(features_types.items(), columns=['features', 'types'])
data_features.head()
# Out:
#           features    types
# 0  markers_0_1_cnt  numeric
# 1  markers_1_1_cnt  numeric
# 2  markers_2_1_cnt  numeric
# 3  markers_3_1_cnt  numeric
# 4  markers_4_1_cnt  numeric

# %% [markdown]
# Создадим отдельно таргет.

# %%
target=['target']

# %%
target = pd.read_parquet('dataset_train.parquet', engine='pyarrow', columns=target)
target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   target  702086 non-null  int32
# dtypes: int32(1)
# memory usage: 2.7 MB

# %%
target.value_counts()
# Out:
# target
# 0         696617
# 1           5469
# dtype: int64

# %% [markdown]
# Выбираю только свою часть признаков.

# %%
my_data_features = data_features.iloc[930:1860]

# %%
my_data_features.types.value_counts()
# Out:
# numeric            851
# categorical_int     69
# categorical_str     10
# Name: types, dtype: int64

# %%
my_data_features.head()
# Out:
#                 features    types
# 930  vas_details_1_3_sum  numeric
# 931  vas_details_2_6_sum  numeric
# 932  vas_details_3_1_sum  numeric
# 933  vas_details_4_3_sum  numeric
# 934  vas_details_5_6_sum  numeric

# %%
my_data_features_num = my_data_features[my_data_features['types'] == 'numeric']

# %%
my_data_features_cat = my_data_features[my_data_features['types'] != 'numeric']

# %%
my_data_features_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 851 entries, 930 to 1859
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   features  851 non-null    object
#  1   types     851 non-null    object
# dtypes: object(2)
# memory usage: 19.9+ KB

# %% [markdown]
# ## Обработка и удаление лишних числовых признаков

# %%
def read_data(left, right):

    # следующие т столбцов, которые будем считывать + target
    columns_to_read = my_data_features_num['features'][left:right].to_list() + ['target']

    # считываем столбцы в файл
    data = pd.read_parquet('dataset_train.parquet', engine='pyarrow', columns=columns_to_read)

    return data

def variance_filter(data, threshold=0.5):

    # считаем дисперсию для каждого признака
    variance = data.var()

    # отбираем те фичи, у которых var > threshold
    selected_features = variance[variance > threshold].index.tolist()

    # собираем в датасет
    filtered_data = data[selected_features + ['target']]
    
    return filtered_data


def corr_with_target(data):

    # чекаем корреляцию с таргетом
    correlation = data.corrwith(data['target']).abs()
    
    # сортируем
    correlation = correlation.sort_values(ascending=False)
    
    return correlation


def common_correlation(data):
    corr_matrix = data.corr().abs()
    
    # выбираем верхний треугольник матрицы корреляции
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool_))
    
    # находим индексы признаков с корреляцией больше 0.90
    to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]
    
    # удаляем эти признаки из датафрейма
    data.drop(data[to_drop], axis=1, inplace=True)
    
    return data


def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=42)
    
    return features_downsampled, target_downsampled

# %% [markdown]
# Создадим датасет с числовыми признаками.

# %%
dataset_num = read_data(0, -1)
dataset_num.head()
# Out:
#    vas_details_1_3_sum  vas_details_2_6_sum  vas_details_3_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_4_3_sum  vas_details_5_6_sum  vas_details_6_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_7_3_sum  vas_details_8_6_sum  vas_details_9_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_10_3_sum  ...  issues_47_6_sum  issues_48_1_sum  \
# 0                   NaN  ...              NaN              NaN
# 1                   NaN  ...              NaN              NaN
# 2                   NaN  ...              NaN              NaN
# 3                   NaN  ...              NaN              NaN
# 4                   NaN  ...              NaN              NaN
#
#    issues_49_3_sum  issues_50_6_sum  issues_51_1_sum  issues_52_3_sum  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    issues_53_6_sum  issues_54_1_sum  issues_55_3_sum  target
# 0              NaN              NaN              NaN       0
# 1              NaN              NaN              NaN       0
# 2              NaN              NaN              NaN       1
# 3              NaN              NaN              NaN       0
# 4              NaN              NaN              NaN       0
#
# [5 rows x 851 columns]

# %%
dataset_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Columns: 851 entries, vas_details_1_3_sum to target
# dtypes: float64(850), int32(1)
# memory usage: 4.4 GB

# %% [markdown]
# Теперь категориальные:

# %%
columns_to_read = my_data_features_cat['features'].to_list()

dataset_cat = pd.read_parquet('dataset_train.parquet', engine='pyarrow', columns=columns_to_read)

# %%
dataset_cat.head()
# Out:
#    communication_availability_4_1_flg  communication_availability_5_1_flg  \
# 0                                   1                                   1
# 1                                   1                                   1
# 2                                   1                                   1
# 3                                   1                                   1
# 4                                   1                                   1
#
#    communication_availability_6_1_flg  social_dem_0_0_flg  \
# 0                                   1                  -1
# 1                                   1                  -1
# 2                                   1                  -1
# 3                                   1                  -1
# 4                                   1                  -1
#
#    communication_availability_7_1_ctg  communication_availability_8_1_flg  \
# 0                                   4                                   0
# 1                                   4                                   0
# 2                                   5                                   0
# 3                                   4                                   0
# 4                                   4                                   0
#
#    communication_availability_9_1_flg  communication_availability_10_1_ctg  \
# 0                                   0                                   50
# 1                                   0                                   50
# 2                                   0                                  100
# 3                                   0                                  100
# 4                                   0                                  100
#
#    communication_availability_11_1_flg  communication_availability_12_1_flg  \
# 0                                    1                                    0
# 1                                    1                                    0
# 2                                    0                                    0
# 3                                    0                                    0
# 4                                    0                                    0
#
#    ...  tariff_plans_17_src_id  deact_react_5_1_ctg  \
# 0  ...                      -1                    0
# 1  ...                      -1                    0
# 2  ...                      -1                    0
# 3  ...                      -1                    0
# 4  ...                      -1                    0
#
#    communication_availability_45_1_flg  user_active_4_1_flg  \
# 0                                    1                    1
# 1                                    1                    1
# 2                                    1                    1
# 3                                    1                    1
# 4                                    1                    1
#
#    deact_react_7_1_ctg  exist_tariff_1_1_flg  tariff_plans_18_1_ctg  \
# 0                    0                     0                   4055
# 1                    0                     0                   4055
# 2                    0                     0                   3755
# 3                    0                     0                   3637
# 4                    0                     0                   2601
#
#    tariff_plans_19_src_id  deact_react_8_1_ctg  deact_react_10_1_ctg
# 0                   51551                   -1                     0
# 1                   51551                   -1                     0
# 2                   51529                   -1                     0
# 3                   51412                   -1                     0
# 4                   51675                   -1                     0
#
# [5 rows x 79 columns]

# %%
dataset_cat = dataset_cat.astype('category')

# %%
dataset_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Data columns (total 79 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   communication_availability_4_1_flg   702086 non-null  category
#  1   communication_availability_5_1_flg   702086 non-null  category
#  2   communication_availability_6_1_flg   702086 non-null  category
#  3   social_dem_0_0_flg                   702086 non-null  category
#  4   communication_availability_7_1_ctg   702086 non-null  category
#  5   communication_availability_8_1_flg   702086 non-null  category
#  6   communication_availability_9_1_flg   702086 non-null  category
#  7   communication_availability_10_1_ctg  702086 non-null  category
#  8   communication_availability_11_1_flg  702086 non-null  category
#  9   communication_availability_12_1_flg  702086 non-null  category
#  10  communication_availability_13_1_flg  702086 non-null  category
#  11  communication_availability_14_1_flg  702086 non-null  category
#  12  communication_availability_15_1_flg  702086 non-null  category
#  13  communication_availability_16_1_flg  702086 non-null  category
#  14  communication_availability_17_1_flg  702086 non-null  category
#  15  communication_availability_18_1_flg  702086 non-null  category
#  16  communication_availability_19_1_flg  702086 non-null  category
#  17  communication_availability_20_1_flg  702086 non-null  category
#  18  communication_availability_21_1_flg  702086 non-null  category
#  19  communication_availability_22_1_flg  702086 non-null  category
#  20  communication_availability_23_1_flg  702086 non-null  category
#  21  communication_availability_24_1_flg  702086 non-null  category
#  22  communication_availability_25_1_flg  702086 non-null  category
#  23  communication_availability_26_1_flg  702086 non-null  category
#  24  communication_availability_27_1_flg  702086 non-null  category
#  25  communication_availability_28_1_flg  702086 non-null  category
#  26  user_active_0_1_flg                  702086 non-null  category
#  27  tariff_plans_12_1_ctg                702086 non-null  category
#  28  tariff_plans_13_src_id               702086 non-null  category
#  29  communication_availability_29_1_flg  702086 non-null  category
#  30  communication_availability_30_1_flg  702086 non-null  category
#  31  communication_availability_31_1_flg  702086 non-null  category
#  32  communication_availability_32_1_ctg  702086 non-null  category
#  33  communication_availability_33_1_flg  702086 non-null  category
#  34  scheme_types_0_1_flg                 702086 non-null  category
#  35  scheme_types_1_1_flg                 702086 non-null  category
#  36  scheme_types_2_1_flg                 702086 non-null  category
#  37  scheme_types_3_1_flg                 702086 non-null  category
#  38  scheme_types_4_1_flg                 702086 non-null  category
#  39  communication_availability_34_1_flg  702086 non-null  category
#  40  communication_availability_35_1_ctg  702086 non-null  category
#  41  communication_availability_36_1_flg  702086 non-null  category
#  42  user_active_1_1_flg                  702086 non-null  category
#  43  communication_availability_37_1_flg  702086 non-null  category
#  44  tariff_plans_14_1_ctg                702086 non-null  category
#  45  tariff_plans_15_src_id               702086 non-null  category
#  46  communication_availability_38_1_flg  702086 non-null  category
#  47  communication_availability_39_1_flg  702086 non-null  category
#  48  communication_availability_40_1_ctg  702086 non-null  category
#  49  communication_availability_41_1_flg  702086 non-null  category
#  50  communication_availability_42_1_ctg  702086 non-null  category
#  51  communication_availability_43_1_flg  702086 non-null  category
#  52  communication_availability_44_1_flg  702086 non-null  category
#  53  user_active_2_0_ctg                  702086 non-null  category
#  54  deact_react_0_1_ctg                  702086 non-null  category
#  55  materials_details_9_1_flg            702086 non-null  category
#  56  materials_details_10_1_flg           702086 non-null  category
#  57  materials_details_11_1_flg           702086 non-null  category
#  58  materials_details_12_1_flg           702086 non-null  category
#  59  info_house_3_0_flg                   702086 non-null  category
#  60  info_house_4_0_flg                   702086 non-null  category
#  61  info_house_7_0_flg                   702086 non-null  category
#  62  info_house_8_0_flg                   702086 non-null  category
#  63  info_house_9_0_flg                   702086 non-null  category
#  64  user_active_3_1_flg                  702086 non-null  category
#  65  deact_react_2_1_ctg                  702086 non-null  category
#  66  exist_tariff_0_1_flg                 702086 non-null  category
#  67  deact_react_3_1_ctg                  702086 non-null  category
#  68  tariff_plans_16_1_ctg                702086 non-null  category
#  69  tariff_plans_17_src_id               702086 non-null  category
#  70  deact_react_5_1_ctg                  702086 non-null  category
#  71  communication_availability_45_1_flg  702086 non-null  category
#  72  user_active_4_1_flg                  702086 non-null  category
#  73  deact_react_7_1_ctg                  702086 non-null  category
#  74  exist_tariff_1_1_flg                 702086 non-null  category
#  75  tariff_plans_18_1_ctg                702086 non-null  category
#  76  tariff_plans_19_src_id               702086 non-null  category
#  77  deact_react_8_1_ctg                  702086 non-null  category
#  78  deact_react_10_1_ctg                 702086 non-null  category
# dtypes: category(79)
# memory usage: 57.7 MB

# %% [markdown]
# Объединим их:

# %%
my_data = dataset_num.join(dataset_cat)

# %%
my_data.head()
# Out:
#    vas_details_1_3_sum  vas_details_2_6_sum  vas_details_3_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_4_3_sum  vas_details_5_6_sum  vas_details_6_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_7_3_sum  vas_details_8_6_sum  vas_details_9_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_10_3_sum  ...  tariff_plans_17_src_id  deact_react_5_1_ctg  \
# 0                   NaN  ...                      -1                    0
# 1                   NaN  ...                      -1                    0
# 2                   NaN  ...                      -1                    0
# 3                   NaN  ...                      -1                    0
# 4                   NaN  ...                      -1                    0
#
#    communication_availability_45_1_flg  user_active_4_1_flg  \
# 0                                    1                    1
# 1                                    1                    1
# 2                                    1                    1
# 3                                    1                    1
# 4                                    1                    1
#
#    deact_react_7_1_ctg  exist_tariff_1_1_flg  tariff_plans_18_1_ctg  \
# 0                    0                     0                   4055
# 1                    0                     0                   4055
# 2                    0                     0                   3755
# 3                    0                     0                   3637
# 4                    0                     0                   2601
#
#    tariff_plans_19_src_id  deact_react_8_1_ctg  deact_react_10_1_ctg
# 0                   51551                   -1                     0
# 1                   51551                   -1                     0
# 2                   51529                   -1                     0
# 3                   51412                   -1                     0
# 4                   51675                   -1                     0
#
# [5 rows x 930 columns]

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Columns: 930 entries, vas_details_1_3_sum to deact_react_10_1_ctg
# dtypes: category(79), float64(850), int32(1)
# memory usage: 4.5 GB

# %% [markdown]
# Удалим столбцы, где больше 1/14 пропусков.

# %%
my_data.dropna(thresh=len(my_data)/14, axis=1, inplace=True)

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Columns: 647 entries, vas_details_1_3_sum to target
# dtypes: float64(646), int32(1)
# memory usage: 3.4 GB

# %%
my_data.drop_duplicates(inplace=True)

# %%
my_data['target'].value_counts()
# Out:
# 0    696446
# 1      5469
# Name: target, dtype: int64

# %% [markdown]
# ## Важность признаков

# %% [markdown]
# Выделим таргет и проведем даунсемплинг.

# %%
features = my_data.drop(['target'], axis=1)
target = my_data['target']

# %%
features_downsampled, target_downsampled = downsample(features, target, 0.01)

# %% [markdown]
# ### Catboost

# %%
cat_features = features_downsampled.select_dtypes(include='category').columns.to_list()

# %%
model_cat = CatBoostClassifier(loss_function='Logloss', verbose=False,\
                               cat_features=cat_features, eval_metric='AUC:hints=skip_train~false',\
                               random_state=42)
model_cat.fit(features_downsampled, target_downsampled)

# %%
cat_imp = pd.Series(model_cat.get_feature_importance(), features_downsampled.columns)
cat_imp.sort_values(ascending=False).head(20)
# Out:
# info_house_5_0_num              2.252200
# user_lifetime_3_0_dt            1.740520
# info_house_6_0_num              1.644187
# area_0_0_num                    1.597189
# user_lifetime_2_1_num           1.406348
# traffic_details_43_1_std        1.371310
# tariff_plans_22_1_min           1.367264
# user_devices_11_1_cnt           1.310490
# tariff_plans_21_1_max           1.294540
# tariff_plans_20_1_ctg           1.293514
# spas_symptoms_agr_104_12_avg    1.269763
# traffic_details_16_1d3_std      1.203165
# spas_symptoms_agr_79_6_sum      1.158814
# traffic_details_49_6_std        1.125087
# traffic_details_44_1_sum        1.111514
# traffic_details_9_3d6_part      1.065838
# traffic_details_67_6_std        1.017557
# traffic_details_10_6_cnt        1.007405
# traffic_details_1_3_cnt         0.931660
# traffic_details_39_3d6_std      0.928013
# dtype: float64

# %% [markdown]
# ### LGBM

# %%
model_lgbm = LGBMClassifier(random_state=42)
model_lgbm.fit(features_downsampled, target_downsampled)
# Out:
# LGBMClassifier(random_state=42)

# %%
lgbm_imp = pd.Series(model_lgbm.feature_importances_, features_downsampled.columns)
lgbm_imp.sort_values(ascending=False).head(100)
# Out:
# area_0_0_num                   82
# info_house_5_0_num             74
# user_lifetime_2_1_num          68
# info_house_6_0_num             68
# traffic_details_43_1_std       46
#                                ..
# traffic_details_36_3_avg       13
# traffic_details_54_3_avg       12
# traffic_details_23_3_sum       12
# traffic_details_15_1d3_avg     12
# spas_symptoms_agr_146_3_avg    12
# Length: 100, dtype: int32

# %%
feature_importance = np.array(model_lgbm.feature_importances_)
feature_names = np.array(features_downsampled.columns)
data = {'feature_names':feature_names,'feature_importance':feature_importance}
fitures_df = pd.DataFrame(data=data, dtype = np.int32).sort_values(by=['feature_importance'], ascending=False).head(25)
fitures_df
# Out:
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_5336\4275587519.py:4: FutureWarning: Could not cast to int32, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   fitures_df = pd.DataFrame(data=data, dtype = np.int32).sort_values(by=['feature_importance'], ascending=False).head(25)
#                     feature_names  feature_importance
# 320                  area_0_0_num                  82
# 465            info_house_5_0_num                  74
# 394         user_lifetime_2_1_num                  68
# 466            info_house_6_0_num                  68
# 365      traffic_details_43_1_std                  46
# 371      traffic_details_49_6_std                  45
# 347    traffic_details_25_3d6_std                  41
# 467         tariff_plans_20_1_ctg                  40
# 482  spas_symptoms_agr_104_12_avg                  36
# 366      traffic_details_44_1_sum                  35
# 370      traffic_details_48_6_avg                  34
# 327    traffic_details_5_1d3_part                  33
# 331    traffic_details_9_3d6_part                  32
# 519  spas_symptoms_agr_153_12_std                  31
# 350      traffic_details_28_6_std                  31
# 368      traffic_details_46_3_std                  30
# 338    traffic_details_16_1d3_std                  29
# 447    spas_symptoms_agr_79_6_sum                  29
# 332      traffic_details_10_6_cnt                  29
# 389      traffic_details_67_6_std                  28
# 361    traffic_details_39_3d6_std                  28
# 360    traffic_details_38_3d6_avg                  28
# 340    traffic_details_18_1d6_avg                  27
# 520  spas_symptoms_agr_154_12_sum                  27
# 346    traffic_details_24_3d6_avg                  26

# %%
important_futures = fitures_df['feature_names'].to_list()
important_futures
# Out:
# ['area_0_0_num',
#  'info_house_5_0_num',
#  'user_lifetime_2_1_num',
#  'info_house_6_0_num',
#  'traffic_details_43_1_std',
#  'traffic_details_49_6_std',
#  'traffic_details_25_3d6_std',
#  'tariff_plans_20_1_ctg',
#  'spas_symptoms_agr_104_12_avg',
#  'traffic_details_44_1_sum',
#  'traffic_details_48_6_avg',
#  'traffic_details_5_1d3_part',
#  'traffic_details_9_3d6_part',
#  'spas_symptoms_agr_153_12_std',
#  'traffic_details_28_6_std',
#  'traffic_details_46_3_std',
#  'traffic_details_16_1d3_std',
#  'spas_symptoms_agr_79_6_sum',
#  'traffic_details_10_6_cnt',
#  'traffic_details_67_6_std',
#  'traffic_details_39_3d6_std',
#  'traffic_details_38_3d6_avg',
#  'traffic_details_18_1d6_avg',
#  'spas_symptoms_agr_154_12_sum',
#  'traffic_details_24_3d6_avg']

# %% [markdown]
# Посмотрим на полученный датасет с важными признаками:

# %%
columns_to_read = fitures_df['feature_names'].to_list() + ['target']

dataset_for_test = pd.read_parquet('dataset_train.parquet', engine='pyarrow', columns=columns_to_read)

# %%
dataset_for_test.head()
# Out:
#    area_0_0_num  info_house_5_0_num  user_lifetime_2_1_num  \
# 0     -0.389706           -0.148010               1.047965
# 1     -0.360158           -0.154880               1.084660
# 2           NaN           -0.159672               0.949020
# 3     -0.104079           -0.137583               0.984405
# 4      1.762342           -0.122424               0.947710
#
#    info_house_6_0_num  traffic_details_43_1_std  traffic_details_49_6_std  \
# 0            0.195933                 -0.003515                 -0.001050
# 1            0.196460                 -0.025559                 -0.001079
# 2            0.186659                 -0.012550                 -0.001077
# 3            0.200200                 -0.019408                 -0.001057
# 4            0.200190                 -0.002080                 -0.001075
#
#    traffic_details_25_3d6_std  tariff_plans_20_1_ctg  \
# 0                    0.211627              -0.748844
# 1                    0.132429              -0.748844
# 2                    0.639417              -0.037023
# 3                    0.997187              -0.037023
# 4                   -2.948140              -0.037023
#
#    spas_symptoms_agr_104_12_avg  traffic_details_44_1_sum  ...  \
# 0                     -0.312153                  0.019032  ...
# 1                     -0.312153                 -0.067416  ...
# 2                      5.598951                 -0.041754  ...
# 3                     -0.312153                 -0.059123  ...
# 4                     -0.312153                  0.094784  ...
#
#    traffic_details_16_1d3_std  spas_symptoms_agr_79_6_sum  \
# 0                   -0.749995                    0.287253
# 1                    0.355538                    0.287253
# 2                   -0.609298                    0.287253
# 3                    2.050425                    0.287253
# 4                   -0.047792                    0.252429
#
#    traffic_details_10_6_cnt  traffic_details_67_6_std  \
# 0                 -0.822154                 -0.001062
# 1                  0.510383                 -0.001064
# 2                 -1.205258                 -0.001064
# 3                 -2.387885                 -0.001063
# 4                 -2.554452                 -0.001059
#
#    traffic_details_39_3d6_std  traffic_details_38_3d6_avg  \
# 0                    0.440552                   -0.211741
# 1                    0.309751                   -0.062897
# 2                    0.931132                    0.003689
# 3                    0.342601                    2.747052
# 4                   -2.726170                   -3.368683
#
#    traffic_details_18_1d6_avg  spas_symptoms_agr_154_12_sum  \
# 0                   -0.352481                      1.203344
# 1                   -0.159590                      1.349770
# 2                   -0.510244                     -3.362484
# 3                    4.926261                      1.416327
# 4                   -1.381120                     -2.723534
#
#    traffic_details_24_3d6_avg  target
# 0                   -0.525663       0
# 1                    0.089350       0
# 2                   -0.189385       1
# 3                    0.765043       0
# 4                   -3.136473       0
#
# [5 rows x 26 columns]

# %%
corr_with_target(dataset_for_test)
# Out:
# target                          1.000000
# spas_symptoms_agr_104_12_avg    0.022623
# tariff_plans_20_1_ctg           0.014144
# traffic_details_67_6_std        0.013640
# traffic_details_49_6_std        0.013639
# traffic_details_28_6_std        0.013639
# traffic_details_48_6_avg        0.013638
# spas_symptoms_agr_154_12_sum    0.012160
# traffic_details_10_6_cnt        0.012063
# spas_symptoms_agr_79_6_sum      0.009684
# info_house_6_0_num              0.006218
# user_lifetime_2_1_num           0.005308
# info_house_5_0_num              0.003528
# traffic_details_24_3d6_avg      0.002566
# area_0_0_num                    0.002379
# traffic_details_44_1_sum        0.001838
# traffic_details_25_3d6_std      0.001823
# traffic_details_16_1d3_std      0.001588
# traffic_details_18_1d6_avg      0.001219
# traffic_details_38_3d6_avg      0.001037
# traffic_details_46_3_std        0.000682
# traffic_details_43_1_std        0.000607
# spas_symptoms_agr_153_12_std    0.000525
# traffic_details_9_3d6_part      0.000421
# traffic_details_39_3d6_std      0.000256
# traffic_details_5_1d3_part      0.000067
# dtype: float64

# %%
common_correlation(dataset_for_test)
# Out:
#         area_0_0_num  info_house_5_0_num  user_lifetime_2_1_num  \
# 0          -0.389706           -0.148010               1.047965
# 1          -0.360158           -0.154880               1.084660
# 2                NaN           -0.159672               0.949020
# 3          -0.104079           -0.137583               0.984405
# 4           1.762342           -0.122424               0.947710
# ...              ...                 ...                    ...
# 702081           NaN            1.536492              -0.577086
# 702082      1.457017            1.550355              -0.675375
# 702083           NaN            1.615714              -0.696999
# 702084           NaN            1.546459              -0.735659
# 702085           NaN            1.582518              -0.516802
#
#         info_house_6_0_num  traffic_details_43_1_std  \
# 0                 0.195933                 -0.003515
# 1                 0.196460                 -0.025559
# 2                 0.186659                 -0.012550
# 3                 0.200200                 -0.019408
# 4                 0.200190                 -0.002080
# ...                    ...                       ...
# 702081           -1.179092                 -0.016526
# 702082           -1.185673                 -0.025548
# 702083           -1.195002                 -0.025158
# 702084           -1.186741                 -0.025581
# 702085           -1.168387                  0.012091
#
#         traffic_details_49_6_std  traffic_details_25_3d6_std  \
# 0                      -0.001050                    0.211627
# 1                      -0.001079                    0.132429
# 2                      -0.001077                    0.639417
# 3                      -0.001057                    0.997187
# 4                      -0.001075                   -2.948140
# ...                          ...                         ...
# 702081                 -0.001068                    0.239084
# 702082                 -0.001078                    0.293960
# 702083                 -0.001079                    0.476393
# 702084                 -0.001079                    0.461791
# 702085                 -0.001074                    0.759100
#
#         tariff_plans_20_1_ctg  spas_symptoms_agr_104_12_avg  \
# 0                   -0.748844                     -0.312153
# 1                   -0.748844                     -0.312153
# 2                   -0.037023                      5.598951
# 3                   -0.037023                     -0.312153
# 4                   -0.037023                     -0.312153
# ...                       ...                           ...
# 702081              -0.037023                     -0.312153
# 702082              -0.037023                     -0.312153
# 702083              -0.037023                     -0.312153
# 702084              -0.037023                     -0.312153
# 702085              -0.037023                     -0.312153
#
#         traffic_details_44_1_sum  ...  spas_symptoms_agr_153_12_std  \
# 0                       0.019032  ...                     -1.427644
# 1                      -0.067416  ...                     -2.039655
# 2                      -0.041754  ...                     -3.600635
# 3                      -0.059123  ...                     -2.439662
# 4                       0.094784  ...                     -0.514963
# ...                          ...  ...                           ...
# 702081                 -0.027575  ...                      0.832499
# 702082                 -0.064967  ...                      0.503083
# 702083                 -0.064145  ...                      0.525879
# 702084                 -0.067542  ...                      0.630811
# 702085                  0.038779  ...                      0.706442
#
#         traffic_details_46_3_std  traffic_details_16_1d3_std  \
# 0                       0.029845                   -0.749995
# 1                      -0.015781                    0.355538
# 2                      -0.013113                   -0.609298
# 3                      -0.014456                    2.050425
# 4                      -0.009937                   -0.047792
# ...                          ...                         ...
# 702081                 -0.002116                    0.314891
# 702082                 -0.013883                   -0.079155
# 702083                 -0.015640                   -0.850405
# 702084                 -0.015828                    0.899857
# 702085                 -0.007869                    1.087915
#
#         spas_symptoms_agr_79_6_sum  traffic_details_10_6_cnt  \
# 0                         0.287253                 -0.822154
# 1                         0.287253                  0.510383
# 2                         0.287253                 -1.205258
# 3                         0.287253                 -2.387885
# 4                         0.252429                 -2.554452
# ...                            ...                       ...
# 702081                    0.252429                 -1.904840
# 702082                   -0.026165                  0.310503
# 702083                    0.043484                 -0.505676
# 702084                    0.287253                 -1.255228
# 702085                    0.287253                  0.776891
#
#         traffic_details_38_3d6_avg  traffic_details_18_1d6_avg  \
# 0                        -0.211741                   -0.352481
# 1                        -0.062897                   -0.159590
# 2                         0.003689                   -0.510244
# 3                         2.747052                    4.926261
# 4                        -3.368683                   -1.381120
# ...                            ...                         ...
# 702081                    0.053374                   -0.137927
# 702082                    0.190668                   -0.166079
# 702083                    0.121722                   -0.408672
# 702084                    1.102863                    0.292478
# 702085                    0.535584                    0.035547
#
#         spas_symptoms_agr_154_12_sum  traffic_details_24_3d6_avg  target
# 0                           1.203344                   -0.525663       0
# 1                           1.349770                    0.089350       0
# 2                          -3.362484                   -0.189385       1
# 3                           1.416327                    0.765043       0
# 4                          -2.723534                   -3.136473       0
# ...                              ...                         ...     ...
# 702081                     -0.394031                   -0.012686       0
# 702082                      0.045247                    0.379010       0
# 702083                      0.058559                    0.307509       0
# 702084                     -0.021310                    0.385311       0
# 702085                     -0.127802                    0.430641       0
#
# [702086 rows x 22 columns]

# %%
corr_matrix = dataset_for_test.corr().abs()
corr_matrix
# Out:
#                               area_0_0_num  info_house_5_0_num  \
# area_0_0_num                      1.000000            0.040719
# info_house_5_0_num                0.040719            1.000000
# user_lifetime_2_1_num             0.064328            0.004217
# info_house_6_0_num                0.037293            0.206370
# traffic_details_43_1_std          0.001369            0.001022
# traffic_details_49_6_std          0.000114            0.001843
# traffic_details_25_3d6_std        0.002640            0.042545
# tariff_plans_20_1_ctg             0.048053            0.051935
# spas_symptoms_agr_104_12_avg      0.007932            0.033091
# traffic_details_44_1_sum          0.006732            0.007576
# traffic_details_5_1d3_part        0.002155            0.001495
# traffic_details_9_3d6_part        0.000185            0.007994
# spas_symptoms_agr_153_12_std      0.013702            0.068870
# traffic_details_46_3_std          0.002429            0.000608
# traffic_details_16_1d3_std        0.009796            0.021373
# spas_symptoms_agr_79_6_sum        0.025265            0.022339
# traffic_details_10_6_cnt          0.028544            0.072351
# traffic_details_38_3d6_avg        0.000802            0.019423
# traffic_details_18_1d6_avg        0.003470            0.030499
# spas_symptoms_agr_154_12_sum      0.013087            0.061681
# traffic_details_24_3d6_avg        0.003125            0.036408
# target                            0.002379            0.003528
#
#                               user_lifetime_2_1_num  info_house_6_0_num  \
# area_0_0_num                               0.064328            0.037293
# info_house_5_0_num                         0.004217            0.206370
# user_lifetime_2_1_num                      1.000000            0.069829
# info_house_6_0_num                         0.069829            1.000000
# traffic_details_43_1_std                   0.003281            0.002599
# traffic_details_49_6_std                   0.001497            0.001408
# traffic_details_25_3d6_std                 0.003402            0.062581
# tariff_plans_20_1_ctg                      0.102620            0.103653
# spas_symptoms_agr_104_12_avg               0.126701            0.025941
# traffic_details_44_1_sum                   0.004528            0.008684
# traffic_details_5_1d3_part                 0.014300            0.037656
# traffic_details_9_3d6_part                 0.031713            0.061295
# spas_symptoms_agr_153_12_std               0.038125            0.361384
# traffic_details_46_3_std                   0.003075            0.002065
# traffic_details_16_1d3_std                 0.007862            0.029247
# spas_symptoms_agr_79_6_sum                 0.110120            0.007732
# traffic_details_10_6_cnt                   0.045839            0.046391
# traffic_details_38_3d6_avg                 0.023178            0.075429
# traffic_details_18_1d6_avg                 0.003328            0.032545
# spas_symptoms_agr_154_12_sum               0.111924            0.218296
# traffic_details_24_3d6_avg                 0.007442            0.060427
# target                                     0.005308            0.006218
#
#                               traffic_details_43_1_std  \
# area_0_0_num                                  0.001369
# info_house_5_0_num                            0.001022
# user_lifetime_2_1_num                         0.003281
# info_house_6_0_num                            0.002599
# traffic_details_43_1_std                      1.000000
# traffic_details_49_6_std                      0.000075
# traffic_details_25_3d6_std                    0.010449
# tariff_plans_20_1_ctg                         0.011201
# spas_symptoms_agr_104_12_avg                  0.002491
# traffic_details_44_1_sum                      0.826252
# traffic_details_5_1d3_part                    0.000133
# traffic_details_9_3d6_part                    0.002627
# spas_symptoms_agr_153_12_std                  0.005560
# traffic_details_46_3_std                      0.167756
# traffic_details_16_1d3_std                    0.023347
# spas_symptoms_agr_79_6_sum                    0.000406
# traffic_details_10_6_cnt                      0.006679
# traffic_details_38_3d6_avg                    0.015148
# traffic_details_18_1d6_avg                    0.048431
# spas_symptoms_agr_154_12_sum                  0.006470
# traffic_details_24_3d6_avg                    0.014131
# target                                        0.000607
#
#                               traffic_details_49_6_std  \
# area_0_0_num                              1.144500e-04
# info_house_5_0_num                        1.842915e-03
# user_lifetime_2_1_num                     1.497296e-03
# info_house_6_0_num                        1.407621e-03
# traffic_details_43_1_std                  7.537455e-05
# traffic_details_49_6_std                  1.000000e+00
# traffic_details_25_3d6_std                3.529871e-03
# tariff_plans_20_1_ctg                     7.612524e-03
# spas_symptoms_agr_104_12_avg              3.859975e-04
# traffic_details_44_1_sum                  3.301549e-05
# traffic_details_5_1d3_part                3.149687e-03
# traffic_details_9_3d6_part                5.274802e-05
# spas_symptoms_agr_153_12_std              8.254325e-04
# traffic_details_46_3_std                  3.622999e-03
# traffic_details_16_1d3_std                2.152046e-03
# spas_symptoms_agr_79_6_sum                3.511790e-04
# traffic_details_10_6_cnt                  6.147284e-07
# traffic_details_38_3d6_avg                4.078607e-03
# traffic_details_18_1d6_avg                1.653896e-03
# spas_symptoms_agr_154_12_sum              1.933529e-04
# traffic_details_24_3d6_avg                3.790902e-03
# target                                    1.363934e-02
#
#                               traffic_details_25_3d6_std  \
# area_0_0_num                                    0.002640
# info_house_5_0_num                              0.042545
# user_lifetime_2_1_num                           0.003402
# info_house_6_0_num                              0.062581
# traffic_details_43_1_std                        0.010449
# traffic_details_49_6_std                        0.003530
# traffic_details_25_3d6_std                      1.000000
# tariff_plans_20_1_ctg                           0.019662
# spas_symptoms_agr_104_12_avg                    0.000629
# traffic_details_44_1_sum                        0.011351
# traffic_details_5_1d3_part                      0.117215
# traffic_details_9_3d6_part                      0.319247
# spas_symptoms_agr_153_12_std                    0.058524
# traffic_details_46_3_std                        0.011518
# traffic_details_16_1d3_std                      0.000178
# spas_symptoms_agr_79_6_sum                      0.020630
# traffic_details_10_6_cnt                        0.069539
# traffic_details_38_3d6_avg                      0.699640
# traffic_details_18_1d6_avg                      0.340946
# spas_symptoms_agr_154_12_sum                    0.057372
# traffic_details_24_3d6_avg                      0.717102
# target                                          0.001823
#
#                               tariff_plans_20_1_ctg  \
# area_0_0_num                               0.048053
# info_house_5_0_num                         0.051935
# user_lifetime_2_1_num                      0.102620
# info_house_6_0_num                         0.103653
# traffic_details_43_1_std                   0.011201
# traffic_details_49_6_std                   0.007613
# traffic_details_25_3d6_std                 0.019662
# tariff_plans_20_1_ctg                      1.000000
# spas_symptoms_agr_104_12_avg               0.031240
# traffic_details_44_1_sum                   0.051537
# traffic_details_5_1d3_part                 0.002509
# traffic_details_9_3d6_part                 0.013193
# spas_symptoms_agr_153_12_std               0.033185
# traffic_details_46_3_std                   0.012775
# traffic_details_16_1d3_std                 0.006916
# spas_symptoms_agr_79_6_sum                 0.103368
# traffic_details_10_6_cnt                   0.009117
# traffic_details_38_3d6_avg                 0.018501
# traffic_details_18_1d6_avg                 0.003813
# spas_symptoms_agr_154_12_sum               0.132633
# traffic_details_24_3d6_avg                 0.011871
# target                                     0.014144
#
#                               spas_symptoms_agr_104_12_avg  \
# area_0_0_num                                      0.007932
# info_house_5_0_num                                0.033091
# user_lifetime_2_1_num                             0.126701
# info_house_6_0_num                                0.025941
# traffic_details_43_1_std                          0.002491
# traffic_details_49_6_std                          0.000386
# traffic_details_25_3d6_std                        0.000629
# tariff_plans_20_1_ctg                             0.031240
# spas_symptoms_agr_104_12_avg                      1.000000
# traffic_details_44_1_sum                          0.007196
# traffic_details_5_1d3_part                        0.004602
# traffic_details_9_3d6_part                        0.013983
# spas_symptoms_agr_153_12_std                      0.235190
# traffic_details_46_3_std                          0.002192
# traffic_details_16_1d3_std                        0.001152
# spas_symptoms_agr_79_6_sum                        0.000763
# traffic_details_10_6_cnt                          0.013228
# traffic_details_38_3d6_avg                        0.010196
# traffic_details_18_1d6_avg                        0.002859
# spas_symptoms_agr_154_12_sum                      0.555231
# traffic_details_24_3d6_avg                        0.009963
# target                                            0.022623
#
#                               traffic_details_44_1_sum  ...  \
# area_0_0_num                                  0.006732  ...
# info_house_5_0_num                            0.007576  ...
# user_lifetime_2_1_num                         0.004528  ...
# info_house_6_0_num                            0.008684  ...
# traffic_details_43_1_std                      0.826252  ...
# traffic_details_49_6_std                      0.000033  ...
# traffic_details_25_3d6_std                    0.011351  ...
# tariff_plans_20_1_ctg                         0.051537  ...
# spas_symptoms_agr_104_12_avg                  0.007196  ...
# traffic_details_44_1_sum                      1.000000  ...
# traffic_details_5_1d3_part                    0.000054  ...
# traffic_details_9_3d6_part                    0.002978  ...
# spas_symptoms_agr_153_12_std                  0.008000  ...
# traffic_details_46_3_std                      0.171154  ...
# traffic_details_16_1d3_std                    0.021339  ...
# spas_symptoms_agr_79_6_sum                    0.000082  ...
# traffic_details_10_6_cnt                      0.020466  ...
# traffic_details_38_3d6_avg                    0.017437  ...
# traffic_details_18_1d6_avg                    0.042585  ...
# spas_symptoms_agr_154_12_sum                  0.005057  ...
# traffic_details_24_3d6_avg                    0.015547  ...
# target                                        0.001838  ...
#
#                               spas_symptoms_agr_153_12_std  \
# area_0_0_num                                      0.013702
# info_house_5_0_num                                0.068870
# user_lifetime_2_1_num                             0.038125
# info_house_6_0_num                                0.361384
# traffic_details_43_1_std                          0.005560
# traffic_details_49_6_std                          0.000825
# traffic_details_25_3d6_std                        0.058524
# tariff_plans_20_1_ctg                             0.033185
# spas_symptoms_agr_104_12_avg                      0.235190
# traffic_details_44_1_sum                          0.008000
# traffic_details_5_1d3_part                        0.041035
# traffic_details_9_3d6_part                        0.089134
# spas_symptoms_agr_153_12_std                      1.000000
# traffic_details_46_3_std                          0.006477
# traffic_details_16_1d3_std                        0.026995
# spas_symptoms_agr_79_6_sum                        0.028160
# traffic_details_10_6_cnt                          0.170112
# traffic_details_38_3d6_avg                        0.093131
# traffic_details_18_1d6_avg                        0.016412
# spas_symptoms_agr_154_12_sum                      0.211537
# traffic_details_24_3d6_avg                        0.058455
# target                                            0.000525
#
#                               traffic_details_46_3_std  \
# area_0_0_num                                  0.002429
# info_house_5_0_num                            0.000608
# user_lifetime_2_1_num                         0.003075
# info_house_6_0_num                            0.002065
# traffic_details_43_1_std                      0.167756
# traffic_details_49_6_std                      0.003623
# traffic_details_25_3d6_std                    0.011518
# tariff_plans_20_1_ctg                         0.012775
# spas_symptoms_agr_104_12_avg                  0.002192
# traffic_details_44_1_sum                      0.171154
# traffic_details_5_1d3_part                    0.000308
# traffic_details_9_3d6_part                    0.002162
# spas_symptoms_agr_153_12_std                  0.006477
# traffic_details_46_3_std                      1.000000
# traffic_details_16_1d3_std                    0.011046
# spas_symptoms_agr_79_6_sum                    0.001515
# traffic_details_10_6_cnt                      0.005768
# traffic_details_38_3d6_avg                    0.019444
# traffic_details_18_1d6_avg                    0.002453
# spas_symptoms_agr_154_12_sum                  0.007626
# traffic_details_24_3d6_avg                    0.018182
# target                                        0.000682
#
#                               traffic_details_16_1d3_std  \
# area_0_0_num                                    0.009796
# info_house_5_0_num                              0.021373
# user_lifetime_2_1_num                           0.007862
# info_house_6_0_num                              0.029247
# traffic_details_43_1_std                        0.023347
# traffic_details_49_6_std                        0.002152
# traffic_details_25_3d6_std                      0.000178
# tariff_plans_20_1_ctg                           0.006916
# spas_symptoms_agr_104_12_avg                    0.001152
# traffic_details_44_1_sum                        0.021339
# traffic_details_5_1d3_part                      0.313430
# traffic_details_9_3d6_part                      0.109025
# spas_symptoms_agr_153_12_std                    0.026995
# traffic_details_46_3_std                        0.011046
# traffic_details_16_1d3_std                      1.000000
# spas_symptoms_agr_79_6_sum                      0.017059
# traffic_details_10_6_cnt                        0.044825
# traffic_details_38_3d6_avg                      0.039134
# traffic_details_18_1d6_avg                      0.575628
# spas_symptoms_agr_154_12_sum                    0.026594
# traffic_details_24_3d6_avg                      0.052186
# target                                          0.001588
#
#                               spas_symptoms_agr_79_6_sum  \
# area_0_0_num                                    0.025265
# info_house_5_0_num                              0.022339
# user_lifetime_2_1_num                           0.110120
# info_house_6_0_num                              0.007732
# traffic_details_43_1_std                        0.000406
# traffic_details_49_6_std                        0.000351
# traffic_details_25_3d6_std                      0.020630
# tariff_plans_20_1_ctg                           0.103368
# spas_symptoms_agr_104_12_avg                    0.000763
# traffic_details_44_1_sum                        0.000082
# traffic_details_5_1d3_part                      0.012707
# traffic_details_9_3d6_part                      0.010910
# spas_symptoms_agr_153_12_std                    0.028160
# traffic_details_46_3_std                        0.001515
# traffic_details_16_1d3_std                      0.017059
# spas_symptoms_agr_79_6_sum                      1.000000
# traffic_details_10_6_cnt                        0.215610
# traffic_details_38_3d6_avg                      0.010007
# traffic_details_18_1d6_avg                      0.009404
# spas_symptoms_agr_154_12_sum                    0.360034
# traffic_details_24_3d6_avg                      0.007051
# target                                          0.009684
#
#                               traffic_details_10_6_cnt  \
# area_0_0_num                              2.854432e-02
# info_house_5_0_num                        7.235112e-02
# user_lifetime_2_1_num                     4.583875e-02
# info_house_6_0_num                        4.639116e-02
# traffic_details_43_1_std                  6.678573e-03
# traffic_details_49_6_std                  6.147284e-07
# traffic_details_25_3d6_std                6.953915e-02
# tariff_plans_20_1_ctg                     9.116763e-03
# spas_symptoms_agr_104_12_avg              1.322816e-02
# traffic_details_44_1_sum                  2.046577e-02
# traffic_details_5_1d3_part                7.083611e-02
# traffic_details_9_3d6_part                2.225769e-01
# spas_symptoms_agr_153_12_std              1.701125e-01
# traffic_details_46_3_std                  5.767856e-03
# traffic_details_16_1d3_std                4.482497e-02
# spas_symptoms_agr_79_6_sum                2.156105e-01
# traffic_details_10_6_cnt                  1.000000e+00
# traffic_details_38_3d6_avg                2.130264e-01
# traffic_details_18_1d6_avg                3.786277e-02
# spas_symptoms_agr_154_12_sum              1.117551e-01
# traffic_details_24_3d6_avg                6.307369e-02
# target                                    1.206347e-02
#
#                               traffic_details_38_3d6_avg  \
# area_0_0_num                                    0.000802
# info_house_5_0_num                              0.019423
# user_lifetime_2_1_num                           0.023178
# info_house_6_0_num                              0.075429
# traffic_details_43_1_std                        0.015148
# traffic_details_49_6_std                        0.004079
# traffic_details_25_3d6_std                      0.699640
# tariff_plans_20_1_ctg                           0.018501
# spas_symptoms_agr_104_12_avg                    0.010196
# traffic_details_44_1_sum                        0.017437
# traffic_details_5_1d3_part                      0.215597
# traffic_details_9_3d6_part                      0.407316
# spas_symptoms_agr_153_12_std                    0.093131
# traffic_details_46_3_std                        0.019444
# traffic_details_16_1d3_std                      0.039134
# spas_symptoms_agr_79_6_sum                      0.010007
# traffic_details_10_6_cnt                        0.213026
# traffic_details_38_3d6_avg                      1.000000
# traffic_details_18_1d6_avg                      0.343370
# spas_symptoms_agr_154_12_sum                    0.050611
# traffic_details_24_3d6_avg                      0.731293
# target                                          0.001037
#
#                               traffic_details_18_1d6_avg  \
# area_0_0_num                                    0.003470
# info_house_5_0_num                              0.030499
# user_lifetime_2_1_num                           0.003328
# info_house_6_0_num                              0.032545
# traffic_details_43_1_std                        0.048431
# traffic_details_49_6_std                        0.001654
# traffic_details_25_3d6_std                      0.340946
# tariff_plans_20_1_ctg                           0.003813
# spas_symptoms_agr_104_12_avg                    0.002859
# traffic_details_44_1_sum                        0.042585
# traffic_details_5_1d3_part                      0.483717
# traffic_details_9_3d6_part                      0.283577
# spas_symptoms_agr_153_12_std                    0.016412
# traffic_details_46_3_std                        0.002453
# traffic_details_16_1d3_std                      0.575628
# spas_symptoms_agr_79_6_sum                      0.009404
# traffic_details_10_6_cnt                        0.037863
# traffic_details_38_3d6_avg                      0.343370
# traffic_details_18_1d6_avg                      1.000000
# spas_symptoms_agr_154_12_sum                    0.009300
# traffic_details_24_3d6_avg                      0.496006
# target                                          0.001219
#
#                               spas_symptoms_agr_154_12_sum  \
# area_0_0_num                                      0.013087
# info_house_5_0_num                                0.061681
# user_lifetime_2_1_num                             0.111924
# info_house_6_0_num                                0.218296
# traffic_details_43_1_std                          0.006470
# traffic_details_49_6_std                          0.000193
# traffic_details_25_3d6_std                        0.057372
# tariff_plans_20_1_ctg                             0.132633
# spas_symptoms_agr_104_12_avg                      0.555231
# traffic_details_44_1_sum                          0.005057
# traffic_details_5_1d3_part                        0.022517
# traffic_details_9_3d6_part                        0.041768
# spas_symptoms_agr_153_12_std                      0.211537
# traffic_details_46_3_std                          0.007626
# traffic_details_16_1d3_std                        0.026594
# spas_symptoms_agr_79_6_sum                        0.360034
# traffic_details_10_6_cnt                          0.111755
# traffic_details_38_3d6_avg                        0.050611
# traffic_details_18_1d6_avg                        0.009300
# spas_symptoms_agr_154_12_sum                      1.000000
# traffic_details_24_3d6_avg                        0.033426
# target                                            0.012160
#
#                               traffic_details_24_3d6_avg    target
# area_0_0_num                                    0.003125  0.002379
# info_house_5_0_num                              0.036408  0.003528
# user_lifetime_2_1_num                           0.007442  0.005308
# info_house_6_0_num                              0.060427  0.006218
# traffic_details_43_1_std                        0.014131  0.000607
# traffic_details_49_6_std                        0.003791  0.013639
# traffic_details_25_3d6_std                      0.717102  0.001823
# tariff_plans_20_1_ctg                           0.011871  0.014144
# spas_symptoms_agr_104_12_avg                    0.009963  0.022623
# traffic_details_44_1_sum                        0.015547  0.001838
# traffic_details_5_1d3_part                      0.146842  0.000067
# traffic_details_9_3d6_part                      0.554223  0.000421
# spas_symptoms_agr_153_12_std                    0.058455  0.000525
# traffic_details_46_3_std                        0.018182  0.000682
# traffic_details_16_1d3_std                      0.052186  0.001588
# spas_symptoms_agr_79_6_sum                      0.007051  0.009684
# traffic_details_10_6_cnt                        0.063074  0.012063
# traffic_details_38_3d6_avg                      0.731293  0.001037
# traffic_details_18_1d6_avg                      0.496006  0.001219
# spas_symptoms_agr_154_12_sum                    0.033426  0.012160
# traffic_details_24_3d6_avg                      1.000000  0.002566
# target                                          0.002566  1.000000
#
# [22 rows x 22 columns]

# %%
dataset_for_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   area_0_0_num                  467367 non-null  float64
#  1   info_house_5_0_num            696471 non-null  float64
#  2   user_lifetime_2_1_num         696827 non-null  float64
#  3   info_house_6_0_num            696471 non-null  float64
#  4   traffic_details_43_1_std      686189 non-null  float64
#  5   traffic_details_49_6_std      686189 non-null  float64
#  6   traffic_details_25_3d6_std    686189 non-null  float64
#  7   tariff_plans_20_1_ctg         697313 non-null  float64
#  8   spas_symptoms_agr_104_12_avg  692032 non-null  float64
#  9   traffic_details_44_1_sum      686189 non-null  float64
#  10  traffic_details_5_1d3_part    686189 non-null  float64
#  11  traffic_details_9_3d6_part    686189 non-null  float64
#  12  spas_symptoms_agr_153_12_std  691863 non-null  float64
#  13  traffic_details_46_3_std      686189 non-null  float64
#  14  traffic_details_16_1d3_std    686189 non-null  float64
#  15  spas_symptoms_agr_79_6_sum    692032 non-null  float64
#  16  traffic_details_10_6_cnt      686189 non-null  float64
#  17  traffic_details_38_3d6_avg    686189 non-null  float64
#  18  traffic_details_18_1d6_avg    686189 non-null  float64
#  19  spas_symptoms_agr_154_12_sum  692032 non-null  float64
#  20  traffic_details_24_3d6_avg    686189 non-null  float64
#  21  target                        702086 non-null  int32
# dtypes: float64(21), int32(1)
# memory usage: 115.2 MB

# %%
important_futures = dataset_for_test.drop('target', axis=1).columns.to_list()
important_futures
# Out:
# ['area_0_0_num',
#  'info_house_5_0_num',
#  'user_lifetime_2_1_num',
#  'info_house_6_0_num',
#  'traffic_details_43_1_std',
#  'traffic_details_49_6_std',
#  'traffic_details_25_3d6_std',
#  'tariff_plans_20_1_ctg',
#  'spas_symptoms_agr_104_12_avg',
#  'traffic_details_44_1_sum',
#  'traffic_details_5_1d3_part',
#  'traffic_details_9_3d6_part',
#  'spas_symptoms_agr_153_12_std',
#  'traffic_details_46_3_std',
#  'traffic_details_16_1d3_std',
#  'spas_symptoms_agr_79_6_sum',
#  'traffic_details_10_6_cnt',
#  'traffic_details_38_3d6_avg',
#  'traffic_details_18_1d6_avg',
#  'spas_symptoms_agr_154_12_sum',
#  'traffic_details_24_3d6_avg']
