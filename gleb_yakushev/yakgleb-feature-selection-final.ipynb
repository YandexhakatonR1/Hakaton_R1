# %% [markdown]
# ## Изучение данных

# %%
import json
import pandas as pd
import numpy as np

from phik import resources
from phik.binning import bin_data
from phik.report import plot_correlation_matrix
from phik import report

import catboost as cb
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from catboost import CatBoostClassifier
from sklearn.utils import shuffle

from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings("ignore")

# %%
f = open('features_types.json')
features_types = json.load(f)

# %%
data_features = pd.DataFrame(features_types.items(), columns=['features', 'types'])
data_features.head()
# Out:
#           features    types
# 0  markers_0_1_cnt  numeric
# 1  markers_1_1_cnt  numeric
# 2  markers_2_1_cnt  numeric
# 3  markers_3_1_cnt  numeric
# 4  markers_4_1_cnt  numeric

# %% [markdown]
# Создадим отдельно таргет.

# %%
target=['target']

# %%
target = pd.read_parquet('dataset_train.parquet', engine='pyarrow', columns=target)
target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   target  702086 non-null  int32
# dtypes: int32(1)
# memory usage: 2.7 MB

# %%
target.value_counts()
# Out:
# target
# 0         696617
# 1           5469
# dtype: int64

# %% [markdown]
# Выбираю только свою часть признаков.

# %%
my_data_features = data_features.iloc[930:1860]

# %%
my_data_features.types.value_counts()
# Out:
# numeric            851
# categorical_int     69
# categorical_str     10
# Name: types, dtype: int64

# %%
my_data_features.head()
# Out:
#                 features    types
# 930  vas_details_1_3_sum  numeric
# 931  vas_details_2_6_sum  numeric
# 932  vas_details_3_1_sum  numeric
# 933  vas_details_4_3_sum  numeric
# 934  vas_details_5_6_sum  numeric

# %%
my_data_features_num = my_data_features[my_data_features['types'] == 'numeric']

# %%
my_data_features_cat = my_data_features[my_data_features['types'] != 'numeric']

# %%
my_data_features_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 851 entries, 930 to 1859
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   features  851 non-null    object
#  1   types     851 non-null    object
# dtypes: object(2)
# memory usage: 19.9+ KB

# %% [markdown]
# ## Обработка и удаление лишних числовых признаков

# %%
def read_data(left, right):

    # следующие т столбцов, которые будем считывать + target
    columns_to_read = my_data_features_num['features'][left:right].to_list() + ['target']

    # считываем столбцы в файл
    data = pd.read_parquet('dataset_train.parquet', engine='pyarrow', columns=columns_to_read)

    return data

def variance_filter(data, threshold=0.5):

    # считаем дисперсию для каждого признака
    variance = data.var()

    # отбираем те фичи, у которых var > threshold
    selected_features = variance[variance > threshold].index.tolist()

    # собираем в датасет
    filtered_data = data[selected_features + ['target']]
    
    return filtered_data


def corr_with_target(data):

    # чекаем корреляцию с таргетом
    correlation = data.corrwith(data['target']).abs()
    
    # сортируем
    correlation = correlation.sort_values(ascending=False)
    
    return correlation


def common_correlation(data, threshold=0.9):
    corr_matrix = data.corr().abs()
    
    # выбираем верхний треугольник матрицы корреляции
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool_))
    
    # находим индексы признаков с корреляцией больше 0.90, удаляем один из них
    to_drop = []
    for i in range(len(upper.columns)):
        for j in range(i):
            if upper.iloc[j, i] >= threshold:
                if upper.columns[i] not in to_drop:
                    to_drop.append(upper.columns[j])
    
    # удаляем эти признаки из датафрейма
    data.drop(to_drop, axis=1, inplace=True)
    
    return data


def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=42)
    
    return features_downsampled, target_downsampled

# %% [markdown]
# Создадим датасет с числовыми признаками.

# %%
dataset_num = read_data(0, -1)
dataset_num.head()
# Out:
#    vas_details_1_3_sum  vas_details_2_6_sum  vas_details_3_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_4_3_sum  vas_details_5_6_sum  vas_details_6_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_7_3_sum  vas_details_8_6_sum  vas_details_9_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_10_3_sum  ...  issues_47_6_sum  issues_48_1_sum  \
# 0                   NaN  ...              NaN              NaN
# 1                   NaN  ...              NaN              NaN
# 2                   NaN  ...              NaN              NaN
# 3                   NaN  ...              NaN              NaN
# 4                   NaN  ...              NaN              NaN
#
#    issues_49_3_sum  issues_50_6_sum  issues_51_1_sum  issues_52_3_sum  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    issues_53_6_sum  issues_54_1_sum  issues_55_3_sum  target
# 0              NaN              NaN              NaN       0
# 1              NaN              NaN              NaN       0
# 2              NaN              NaN              NaN       1
# 3              NaN              NaN              NaN       0
# 4              NaN              NaN              NaN       0
#
# [5 rows x 851 columns]

# %%
dataset_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Columns: 851 entries, vas_details_1_3_sum to target
# dtypes: float64(850), int32(1)
# memory usage: 4.4 GB

# %% [markdown]
# Теперь категориальные:

# %%
columns_to_read = my_data_features_cat['features'].to_list()

dataset_cat = pd.read_parquet('dataset_train.parquet', engine='pyarrow', columns=columns_to_read)

# %%
dataset_cat.head()
# Out:
#    communication_availability_4_1_flg  communication_availability_5_1_flg  \
# 0                                   1                                   1
# 1                                   1                                   1
# 2                                   1                                   1
# 3                                   1                                   1
# 4                                   1                                   1
#
#    communication_availability_6_1_flg  social_dem_0_0_flg  \
# 0                                   1                  -1
# 1                                   1                  -1
# 2                                   1                  -1
# 3                                   1                  -1
# 4                                   1                  -1
#
#    communication_availability_7_1_ctg  communication_availability_8_1_flg  \
# 0                                   4                                   0
# 1                                   4                                   0
# 2                                   5                                   0
# 3                                   4                                   0
# 4                                   4                                   0
#
#    communication_availability_9_1_flg  communication_availability_10_1_ctg  \
# 0                                   0                                   50
# 1                                   0                                   50
# 2                                   0                                  100
# 3                                   0                                  100
# 4                                   0                                  100
#
#    communication_availability_11_1_flg  communication_availability_12_1_flg  \
# 0                                    1                                    0
# 1                                    1                                    0
# 2                                    0                                    0
# 3                                    0                                    0
# 4                                    0                                    0
#
#    ...  tariff_plans_17_src_id  deact_react_5_1_ctg  \
# 0  ...                      -1                    0
# 1  ...                      -1                    0
# 2  ...                      -1                    0
# 3  ...                      -1                    0
# 4  ...                      -1                    0
#
#    communication_availability_45_1_flg  user_active_4_1_flg  \
# 0                                    1                    1
# 1                                    1                    1
# 2                                    1                    1
# 3                                    1                    1
# 4                                    1                    1
#
#    deact_react_7_1_ctg  exist_tariff_1_1_flg  tariff_plans_18_1_ctg  \
# 0                    0                     0                   4055
# 1                    0                     0                   4055
# 2                    0                     0                   3755
# 3                    0                     0                   3637
# 4                    0                     0                   2601
#
#    tariff_plans_19_src_id  deact_react_8_1_ctg  deact_react_10_1_ctg
# 0                   51551                   -1                     0
# 1                   51551                   -1                     0
# 2                   51529                   -1                     0
# 3                   51412                   -1                     0
# 4                   51675                   -1                     0
#
# [5 rows x 79 columns]

# %%
dataset_cat = dataset_cat.astype('category')

# %%
dataset_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Data columns (total 79 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   communication_availability_4_1_flg   702086 non-null  category
#  1   communication_availability_5_1_flg   702086 non-null  category
#  2   communication_availability_6_1_flg   702086 non-null  category
#  3   social_dem_0_0_flg                   702086 non-null  category
#  4   communication_availability_7_1_ctg   702086 non-null  category
#  5   communication_availability_8_1_flg   702086 non-null  category
#  6   communication_availability_9_1_flg   702086 non-null  category
#  7   communication_availability_10_1_ctg  702086 non-null  category
#  8   communication_availability_11_1_flg  702086 non-null  category
#  9   communication_availability_12_1_flg  702086 non-null  category
#  10  communication_availability_13_1_flg  702086 non-null  category
#  11  communication_availability_14_1_flg  702086 non-null  category
#  12  communication_availability_15_1_flg  702086 non-null  category
#  13  communication_availability_16_1_flg  702086 non-null  category
#  14  communication_availability_17_1_flg  702086 non-null  category
#  15  communication_availability_18_1_flg  702086 non-null  category
#  16  communication_availability_19_1_flg  702086 non-null  category
#  17  communication_availability_20_1_flg  702086 non-null  category
#  18  communication_availability_21_1_flg  702086 non-null  category
#  19  communication_availability_22_1_flg  702086 non-null  category
#  20  communication_availability_23_1_flg  702086 non-null  category
#  21  communication_availability_24_1_flg  702086 non-null  category
#  22  communication_availability_25_1_flg  702086 non-null  category
#  23  communication_availability_26_1_flg  702086 non-null  category
#  24  communication_availability_27_1_flg  702086 non-null  category
#  25  communication_availability_28_1_flg  702086 non-null  category
#  26  user_active_0_1_flg                  702086 non-null  category
#  27  tariff_plans_12_1_ctg                702086 non-null  category
#  28  tariff_plans_13_src_id               702086 non-null  category
#  29  communication_availability_29_1_flg  702086 non-null  category
#  30  communication_availability_30_1_flg  702086 non-null  category
#  31  communication_availability_31_1_flg  702086 non-null  category
#  32  communication_availability_32_1_ctg  702086 non-null  category
#  33  communication_availability_33_1_flg  702086 non-null  category
#  34  scheme_types_0_1_flg                 702086 non-null  category
#  35  scheme_types_1_1_flg                 702086 non-null  category
#  36  scheme_types_2_1_flg                 702086 non-null  category
#  37  scheme_types_3_1_flg                 702086 non-null  category
#  38  scheme_types_4_1_flg                 702086 non-null  category
#  39  communication_availability_34_1_flg  702086 non-null  category
#  40  communication_availability_35_1_ctg  702086 non-null  category
#  41  communication_availability_36_1_flg  702086 non-null  category
#  42  user_active_1_1_flg                  702086 non-null  category
#  43  communication_availability_37_1_flg  702086 non-null  category
#  44  tariff_plans_14_1_ctg                702086 non-null  category
#  45  tariff_plans_15_src_id               702086 non-null  category
#  46  communication_availability_38_1_flg  702086 non-null  category
#  47  communication_availability_39_1_flg  702086 non-null  category
#  48  communication_availability_40_1_ctg  702086 non-null  category
#  49  communication_availability_41_1_flg  702086 non-null  category
#  50  communication_availability_42_1_ctg  702086 non-null  category
#  51  communication_availability_43_1_flg  702086 non-null  category
#  52  communication_availability_44_1_flg  702086 non-null  category
#  53  user_active_2_0_ctg                  702086 non-null  category
#  54  deact_react_0_1_ctg                  702086 non-null  category
#  55  materials_details_9_1_flg            702086 non-null  category
#  56  materials_details_10_1_flg           702086 non-null  category
#  57  materials_details_11_1_flg           702086 non-null  category
#  58  materials_details_12_1_flg           702086 non-null  category
#  59  info_house_3_0_flg                   702086 non-null  category
#  60  info_house_4_0_flg                   702086 non-null  category
#  61  info_house_7_0_flg                   702086 non-null  category
#  62  info_house_8_0_flg                   702086 non-null  category
#  63  info_house_9_0_flg                   702086 non-null  category
#  64  user_active_3_1_flg                  702086 non-null  category
#  65  deact_react_2_1_ctg                  702086 non-null  category
#  66  exist_tariff_0_1_flg                 702086 non-null  category
#  67  deact_react_3_1_ctg                  702086 non-null  category
#  68  tariff_plans_16_1_ctg                702086 non-null  category
#  69  tariff_plans_17_src_id               702086 non-null  category
#  70  deact_react_5_1_ctg                  702086 non-null  category
#  71  communication_availability_45_1_flg  702086 non-null  category
#  72  user_active_4_1_flg                  702086 non-null  category
#  73  deact_react_7_1_ctg                  702086 non-null  category
#  74  exist_tariff_1_1_flg                 702086 non-null  category
#  75  tariff_plans_18_1_ctg                702086 non-null  category
#  76  tariff_plans_19_src_id               702086 non-null  category
#  77  deact_react_8_1_ctg                  702086 non-null  category
#  78  deact_react_10_1_ctg                 702086 non-null  category
# dtypes: category(79)
# memory usage: 57.7 MB

# %% [markdown]
# Объединим их:

# %%
my_data = dataset_num.join(dataset_cat)

# %%
my_data.head()
# Out:
#    vas_details_1_3_sum  vas_details_2_6_sum  vas_details_3_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_4_3_sum  vas_details_5_6_sum  vas_details_6_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_7_3_sum  vas_details_8_6_sum  vas_details_9_1_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    vas_details_10_3_sum  ...  tariff_plans_17_src_id  deact_react_5_1_ctg  \
# 0                   NaN  ...                      -1                    0
# 1                   NaN  ...                      -1                    0
# 2                   NaN  ...                      -1                    0
# 3                   NaN  ...                      -1                    0
# 4                   NaN  ...                      -1                    0
#
#    communication_availability_45_1_flg  user_active_4_1_flg  \
# 0                                    1                    1
# 1                                    1                    1
# 2                                    1                    1
# 3                                    1                    1
# 4                                    1                    1
#
#    deact_react_7_1_ctg  exist_tariff_1_1_flg  tariff_plans_18_1_ctg  \
# 0                    0                     0                   4055
# 1                    0                     0                   4055
# 2                    0                     0                   3755
# 3                    0                     0                   3637
# 4                    0                     0                   2601
#
#    tariff_plans_19_src_id  deact_react_8_1_ctg  deact_react_10_1_ctg
# 0                   51551                   -1                     0
# 1                   51551                   -1                     0
# 2                   51529                   -1                     0
# 3                   51412                   -1                     0
# 4                   51675                   -1                     0
#
# [5 rows x 930 columns]

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Columns: 930 entries, vas_details_1_3_sum to deact_react_10_1_ctg
# dtypes: category(79), float64(850), int32(1)
# memory usage: 4.5 GB

# %% [markdown]
# Удалим столбцы, где больше 1/10 пропусков.

# %%
my_data.dropna(thresh=len(my_data)/10, axis=1, inplace=True)

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Columns: 925 entries, vas_details_1_3_sum to deact_react_10_1_ctg
# dtypes: category(79), float64(845), int32(1)
# memory usage: 4.5 GB

# %% [markdown]
# Фильтруем по дисперсии.

# %%
my_data = variance_filter(my_data)

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Columns: 753 entries, vas_details_1_3_sum to target
# dtypes: float64(752), int32(1)
# memory usage: 3.9 GB

# %% [markdown]
# Чекаем корреляцию с таргетом:

# %%
corr_with_target(my_data)
# Out:
# target                         1.000000
# movix_channels_105_1_sumpct    0.038317
# movix_channels_106_3_sumpct    0.038317
# movix_channels_107_6_sumpct    0.038317
# movix_channels_3_1_part        0.030670
#                                  ...
# spas_symptoms_int_159_1_cnt    0.000049
# spas_symptoms_int_60_1_cnt     0.000040
# issues_22_3_sum                0.000029
# traffic_details_34_1d6_avg     0.000021
# traffic_details_60_1_avg       0.000020
# Length: 753, dtype: float64

# %% [markdown]
# Удаляем 1 признак из каждой пары коррелирующих признаков.

# %%
common_correlation(my_data)
# Out:
#         vas_details_5_6_sum  vas_details_6_1_sum  vas_details_7_3_sum  \
# 0                       NaN                  NaN                  NaN
# 1                       NaN                  NaN                  NaN
# 2                       NaN                  NaN                  NaN
# 3                       NaN                  NaN                  NaN
# 4                       NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 702081                  NaN                  NaN                  NaN
# 702082                  NaN                  NaN                  NaN
# 702083                  NaN                  NaN                  NaN
# 702084                  NaN                  NaN                  NaN
# 702085            -0.635287            -0.015915            -0.034668
#
#         vas_details_8_6_sum  vas_details_18_1_mean  vas_details_19_1d3_mean  \
# 0                       NaN                    NaN                      NaN
# 1                       NaN                    NaN                      NaN
# 2                       NaN                    NaN                      NaN
# 3                       NaN                    NaN                      NaN
# 4                       NaN                    NaN                      NaN
# ...                     ...                    ...                      ...
# 702081                  NaN                    NaN                      NaN
# 702082                  NaN                    NaN                      NaN
# 702083                  NaN                    NaN                      NaN
# 702084                  NaN                    NaN                      NaN
# 702085            -0.045389              -0.735849                -1.723014
#
#         vas_details_20_1d6_mean  vas_details_22_3d6_mean  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 702081                      NaN                      NaN
# 702082                      NaN                      NaN
# 702083                      NaN                      NaN
# 702084                      NaN                      NaN
# 702085                -1.140371                 -2.05513
#
#         vas_details_23_6_mean  vas_details_24_1_meanpct  ...  issues_47_6_sum  \
# 0                         NaN                       NaN  ...              NaN
# 1                         NaN                       NaN  ...              NaN
# 2                         NaN                       NaN  ...              NaN
# 3                         NaN                       NaN  ...              NaN
# 4                         NaN                       NaN  ...              NaN
# ...                       ...                       ...  ...              ...
# 702081                    NaN                       NaN  ...        -0.484357
# 702082                    NaN                       NaN  ...              NaN
# 702083                    NaN                       NaN  ...              NaN
# 702084                    NaN                       NaN  ...              NaN
# 702085              -0.757563                 -1.414331  ...        -0.484357
#
#         issues_48_1_sum  issues_49_3_sum  issues_50_6_sum  issues_51_1_sum  \
# 0                   NaN              NaN              NaN              NaN
# 1                   NaN              NaN              NaN              NaN
# 2                   NaN              NaN              NaN              NaN
# 3                   NaN              NaN              NaN              NaN
# 4                   NaN              NaN              NaN              NaN
# ...                 ...              ...              ...              ...
# 702081        -0.083936        -0.167973         -0.22824        -0.028022
# 702082              NaN              NaN              NaN              NaN
# 702083              NaN              NaN              NaN              NaN
# 702084              NaN              NaN              NaN              NaN
# 702085        -0.083936        -0.167973         -0.22824        -0.028022
#
#         issues_52_3_sum  issues_53_6_sum  issues_54_1_sum  issues_55_3_sum  \
# 0                   NaN              NaN              NaN              NaN
# 1                   NaN              NaN              NaN              NaN
# 2                   NaN              NaN              NaN              NaN
# 3                   NaN              NaN              NaN              NaN
# 4                   NaN              NaN              NaN              NaN
# ...                 ...              ...              ...              ...
# 702081        -0.049234         -0.05957        -0.014744        -0.026752
# 702082              NaN              NaN              NaN              NaN
# 702083              NaN              NaN              NaN              NaN
# 702084              NaN              NaN              NaN              NaN
# 702085        -0.049234         -0.05957        -0.014744        -0.026752
#
#         target
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0
# ...        ...
# 702081       0
# 702082       0
# 702083       0
# 702084       0
# 702085       0
#
# [702086 rows x 340 columns]

# %% [markdown]
# Дропаем дубликаты.

# %%
my_data.drop_duplicates(inplace=True)

# %%
my_data['target'].value_counts()
# Out:
# 0    696446
# 1      5469
# Name: target, dtype: int64

# %% [markdown]
# ## Важность признаков

# %% [markdown]
# Выделим таргет и проведем даунсемплинг, затем посмотрим на важность признаков, обучив модель.

# %%
features = my_data.drop(['target'], axis=1)
target = my_data['target']

# %%
features_downsampled, target_downsampled = downsample(features, target, 0.01)

# %% [markdown]
# ### LGBM

# %%
model_lgbm = LGBMClassifier(random_state=42)
model_lgbm.fit(features_downsampled, target_downsampled)
# Out:
# LGBMClassifier(random_state=42)

# %%
lgbm_imp = pd.Series(model_lgbm.feature_importances_, features_downsampled.columns)
lgbm_imp.sort_values(ascending=False).head(100)
# Out:
# info_house_5_0_num             92
# area_0_0_num                   89
# user_lifetime_3_0_dt           80
# info_house_6_0_num             79
# traffic_details_43_1_std       78
#                                ..
# movix_channels_80_6_sum         6
# vas_details_57_3d6_mean         6
# movix_channels_11_6_avg         6
# spas_symptoms_agr_192_1_std     6
# spas_symptoms_iptv_1_1_cnt      6
# Length: 100, dtype: int32

# %%
feature_importance = np.array(model_lgbm.feature_importances_)
feature_names = np.array(features_downsampled.columns)
data = {'feature_names':feature_names,'feature_importance':feature_importance}
fitures_df = pd.DataFrame(data=data, dtype = np.int32).sort_values(by=['feature_importance'], ascending=False).head(25)
fitures_df
# Out:
#                     feature_names  feature_importance
# 239            info_house_5_0_num                  92
# 128                  area_0_0_num                  89
# 236          user_lifetime_3_0_dt                  80
# 240            info_house_6_0_num                  79
# 151      traffic_details_43_1_std                  78
# 261  spas_symptoms_agr_154_12_sum                  76
# 156      traffic_details_62_1_sum                  72
# 150    traffic_details_39_3d6_std                  67
# 153      traffic_details_47_3_sum                  61
# 241         tariff_plans_22_1_min                  61
# 158      traffic_details_68_6_sum                  59
# 134    traffic_details_9_3d6_part                  58
# 250  spas_symptoms_agr_105_12_std                  57
# 148      traffic_details_37_3_std                  54
# 152      traffic_details_44_1_sum                  52
# 147    traffic_details_35_1d6_std                  52
# 132    traffic_details_5_1d3_part                  51
# 145    traffic_details_33_1d3_std                  50
# 131       traffic_details_2_6_cnt                  50
# 259   spas_symptoms_agr_150_6_std                  46
# 143      traffic_details_31_1_std                  45
# 154      traffic_details_53_1_sum                  42
# 157      traffic_details_65_3_sum                  41
# 149    traffic_details_38_3d6_avg                  41
# 139    traffic_details_18_1d6_avg                  40

# %%
important_futures = fitures_df['feature_names'].to_list()
important_futures
# Out:
# ['info_house_5_0_num',
#  'area_0_0_num',
#  'user_lifetime_3_0_dt',
#  'info_house_6_0_num',
#  'traffic_details_43_1_std',
#  'spas_symptoms_agr_154_12_sum',
#  'traffic_details_62_1_sum',
#  'traffic_details_39_3d6_std',
#  'traffic_details_47_3_sum',
#  'tariff_plans_22_1_min',
#  'traffic_details_68_6_sum',
#  'traffic_details_9_3d6_part',
#  'spas_symptoms_agr_105_12_std',
#  'traffic_details_37_3_std',
#  'traffic_details_44_1_sum',
#  'traffic_details_35_1d6_std',
#  'traffic_details_5_1d3_part',
#  'traffic_details_33_1d3_std',
#  'traffic_details_2_6_cnt',
#  'spas_symptoms_agr_150_6_std',
#  'traffic_details_31_1_std',
#  'traffic_details_53_1_sum',
#  'traffic_details_65_3_sum',
#  'traffic_details_38_3d6_avg',
#  'traffic_details_18_1d6_avg']

# %% [markdown]
# Посмотрим на полученный датасет с важными признаками:

# %%
columns_to_read = fitures_df['feature_names'].to_list() + ['target']

dataset_for_test = pd.read_parquet('dataset_train.parquet', engine='pyarrow', columns=columns_to_read)

# %%
dataset_for_test.head()
# Out:
#    info_house_5_0_num  area_0_0_num  user_lifetime_3_0_dt  info_house_6_0_num  \
# 0           -0.148010     -0.389706              1.047656            0.195933
# 1           -0.154880     -0.360158              1.084350            0.196460
# 2           -0.159672           NaN              0.948712            0.186659
# 3           -0.137583     -0.104079              0.984096            0.200200
# 4           -0.122424      1.762342              0.948057            0.200190
#
#    traffic_details_43_1_std  spas_symptoms_agr_154_12_sum  \
# 0                 -0.003515                      1.203344
# 1                 -0.025559                      1.349770
# 2                 -0.012550                     -3.362484
# 3                 -0.019408                      1.416327
# 4                 -0.002080                     -2.723534
#
#    traffic_details_62_1_sum  traffic_details_39_3d6_std  \
# 0                 -0.010768                    0.440552
# 1                 -0.048241                    0.309751
# 2                 -0.024261                    0.931132
# 3                  0.017605                    0.342601
# 4                  0.308970                   -2.726170
#
#    traffic_details_47_3_sum  tariff_plans_22_1_min  ...  \
# 0                  0.095315              -0.756059  ...
# 1                 -0.050774              -0.756059  ...
# 2                 -0.043705              -0.031473  ...
# 3                 -0.045270              -0.031473  ...
# 4                 -0.000405              -0.031473  ...
#
#    traffic_details_5_1d3_part  traffic_details_33_1d3_std  \
# 0                    0.660512                   -0.871500
# 1                   -0.092461                    0.360753
# 2                   -0.699221                   -0.767814
# 3                    7.574837                    0.393296
# 4                   -2.582269                   -1.728001
#
#    traffic_details_2_6_cnt  spas_symptoms_agr_150_6_std  \
# 0                 0.459777                    -2.529417
# 1                 0.485644                    -2.529417
# 2                 0.485644                    -2.276879
# 3                 0.278705                    -3.144847
# 4                 0.485644                    -2.274524
#
#    traffic_details_31_1_std  traffic_details_53_1_sum  \
# 0                 -0.018738                  0.075392
# 1                 -0.025831                 -0.060625
# 2                 -0.024223                  0.017799
# 3                 -0.022379                  0.082724
# 4                 -0.027783                  1.985725
#
#    traffic_details_65_3_sum  traffic_details_38_3d6_avg  \
# 0                 -0.000528                   -0.211741
# 1                 -0.008240                   -0.062897
# 2                 -0.004517                    0.003689
# 3                  0.001592                    2.747052
# 4                  0.031185                   -3.368683
#
#    traffic_details_18_1d6_avg  target
# 0                   -0.352481       0
# 1                   -0.159590       0
# 2                   -0.510244       1
# 3                    4.926261       0
# 4                   -1.381120       0
#
# [5 rows x 26 columns]

# %%
dataset_for_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   info_house_5_0_num            696471 non-null  float64
#  1   area_0_0_num                  467367 non-null  float64
#  2   user_lifetime_3_0_dt          696827 non-null  float64
#  3   info_house_6_0_num            696471 non-null  float64
#  4   traffic_details_43_1_std      686189 non-null  float64
#  5   spas_symptoms_agr_154_12_sum  692032 non-null  float64
#  6   traffic_details_62_1_sum      686189 non-null  float64
#  7   traffic_details_39_3d6_std    686189 non-null  float64
#  8   traffic_details_47_3_sum      686189 non-null  float64
#  9   tariff_plans_22_1_min         697313 non-null  float64
#  10  traffic_details_68_6_sum      686189 non-null  float64
#  11  traffic_details_9_3d6_part    686189 non-null  float64
#  12  spas_symptoms_agr_105_12_std  691863 non-null  float64
#  13  traffic_details_37_3_std      686189 non-null  float64
#  14  traffic_details_44_1_sum      686189 non-null  float64
#  15  traffic_details_35_1d6_std    686189 non-null  float64
#  16  traffic_details_5_1d3_part    686189 non-null  float64
#  17  traffic_details_33_1d3_std    686189 non-null  float64
#  18  traffic_details_2_6_cnt       686189 non-null  float64
#  19  spas_symptoms_agr_150_6_std   691863 non-null  float64
#  20  traffic_details_31_1_std      686189 non-null  float64
#  21  traffic_details_53_1_sum      686189 non-null  float64
#  22  traffic_details_65_3_sum      686189 non-null  float64
#  23  traffic_details_38_3d6_avg    686189 non-null  float64
#  24  traffic_details_18_1d6_avg    686189 non-null  float64
#  25  target                        702086 non-null  int32
# dtypes: float64(25), int32(1)
# memory usage: 136.6 MB

# %% [markdown]
# Посмотрим на корреляцию с таргетом, затем друг с другом. отбросим признаки с высокой корреляцией.

# %%
corr_matrix = dataset_for_test.corr().abs()
corr_matrix
# Out:
#                               info_house_5_0_num  area_0_0_num  \
# info_house_5_0_num                      1.000000      0.040719
# area_0_0_num                            0.040719      1.000000
# user_lifetime_3_0_dt                    0.004210      0.064324
# info_house_6_0_num                      0.206370      0.037293
# traffic_details_43_1_std                0.001022      0.001369
# spas_symptoms_agr_154_12_sum            0.061681      0.013087
# traffic_details_62_1_sum                0.006272      0.005349
# traffic_details_39_3d6_std              0.027056      0.003732
# traffic_details_47_3_sum                0.005016      0.008863
# tariff_plans_22_1_min                   0.051886      0.047930
# traffic_details_68_6_sum                0.001841      0.000115
# traffic_details_9_3d6_part              0.007994      0.000185
# spas_symptoms_agr_105_12_std            0.076162      0.033046
# traffic_details_37_3_std                0.000582      0.001177
# traffic_details_44_1_sum                0.007576      0.006732
# traffic_details_35_1d6_std              0.033491      0.011406
# traffic_details_5_1d3_part              0.001495      0.002155
# traffic_details_33_1d3_std              0.008226      0.010953
# traffic_details_2_6_cnt                 0.003615      0.059998
# spas_symptoms_agr_150_6_std             0.066970      0.027272
# traffic_details_31_1_std                0.001653      0.001737
# traffic_details_53_1_sum                0.003572      0.003590
# traffic_details_65_3_sum                0.001154      0.007523
# traffic_details_38_3d6_avg              0.019423      0.000802
# traffic_details_18_1d6_avg              0.030499      0.003470
# target                                  0.003528      0.002379
#
#                               user_lifetime_3_0_dt  info_house_6_0_num  \
# info_house_5_0_num                        0.004210            0.206370
# area_0_0_num                              0.064324            0.037293
# user_lifetime_3_0_dt                      1.000000            0.069815
# info_house_6_0_num                        0.069815            1.000000
# traffic_details_43_1_std                  0.003282            0.002599
# spas_symptoms_agr_154_12_sum              0.111928            0.218296
# traffic_details_62_1_sum                  0.000753            0.004802
# traffic_details_39_3d6_std                0.015377            0.073113
# traffic_details_47_3_sum                  0.003746            0.006387
# tariff_plans_22_1_min                     0.102897            0.104209
# traffic_details_68_6_sum                  0.001498            0.001405
# traffic_details_9_3d6_part                0.031707            0.061295
# spas_symptoms_agr_105_12_std              0.153520            0.037987
# traffic_details_37_3_std                  0.002472            0.005067
# traffic_details_44_1_sum                  0.004527            0.008684
# traffic_details_35_1d6_std                0.013566            0.051567
# traffic_details_5_1d3_part                0.014301            0.037656
# traffic_details_33_1d3_std                0.019893            0.038740
# traffic_details_2_6_cnt                   0.166342            0.015759
# spas_symptoms_agr_150_6_std               0.037267            0.444482
# traffic_details_31_1_std                  0.004374            0.004075
# traffic_details_53_1_sum                  0.005686            0.007471
# traffic_details_65_3_sum                  0.000686            0.000328
# traffic_details_38_3d6_avg                0.023168            0.075429
# traffic_details_18_1d6_avg                0.003332            0.032545
# target                                    0.005310            0.006218
#
#                               traffic_details_43_1_std  \
# info_house_5_0_num                            0.001022
# area_0_0_num                                  0.001369
# user_lifetime_3_0_dt                          0.003282
# info_house_6_0_num                            0.002599
# traffic_details_43_1_std                      1.000000
# spas_symptoms_agr_154_12_sum                  0.006470
# traffic_details_62_1_sum                      0.393263
# traffic_details_39_3d6_std                    0.010201
# traffic_details_47_3_sum                      0.178213
# tariff_plans_22_1_min                         0.011179
# traffic_details_68_6_sum                      0.000010
# traffic_details_9_3d6_part                    0.002627
# spas_symptoms_agr_105_12_std                  0.002578
# traffic_details_37_3_std                      0.097739
# traffic_details_44_1_sum                      0.826252
# traffic_details_35_1d6_std                    0.031382
# traffic_details_5_1d3_part                    0.000133
# traffic_details_33_1d3_std                    0.024626
# traffic_details_2_6_cnt                       0.002747
# spas_symptoms_agr_150_6_std                   0.006879
# traffic_details_31_1_std                      0.420218
# traffic_details_53_1_sum                      0.182965
# traffic_details_65_3_sum                      0.015042
# traffic_details_38_3d6_avg                    0.015148
# traffic_details_18_1d6_avg                    0.048431
# target                                        0.000607
#
#                               spas_symptoms_agr_154_12_sum  \
# info_house_5_0_num                                0.061681
# area_0_0_num                                      0.013087
# user_lifetime_3_0_dt                              0.111928
# info_house_6_0_num                                0.218296
# traffic_details_43_1_std                          0.006470
# spas_symptoms_agr_154_12_sum                      1.000000
# traffic_details_62_1_sum                          0.004876
# traffic_details_39_3d6_std                        0.062147
# traffic_details_47_3_sum                          0.005199
# tariff_plans_22_1_min                             0.134159
# traffic_details_68_6_sum                          0.000183
# traffic_details_9_3d6_part                        0.041768
# spas_symptoms_agr_105_12_std                      0.387686
# traffic_details_37_3_std                          0.012401
# traffic_details_44_1_sum                          0.005057
# traffic_details_35_1d6_std                        0.050805
# traffic_details_5_1d3_part                        0.022517
# traffic_details_33_1d3_std                        0.038810
# traffic_details_2_6_cnt                           0.305884
# spas_symptoms_agr_150_6_std                       0.429283
# traffic_details_31_1_std                          0.013126
# traffic_details_53_1_sum                          0.001869
# traffic_details_65_3_sum                          0.000133
# traffic_details_38_3d6_avg                        0.050611
# traffic_details_18_1d6_avg                        0.009300
# target                                            0.012160
#
#                               traffic_details_62_1_sum  \
# info_house_5_0_num                            0.006272
# area_0_0_num                                  0.005349
# user_lifetime_3_0_dt                          0.000753
# info_house_6_0_num                            0.004802
# traffic_details_43_1_std                      0.393263
# spas_symptoms_agr_154_12_sum                  0.004876
# traffic_details_62_1_sum                      1.000000
# traffic_details_39_3d6_std                    0.008562
# traffic_details_47_3_sum                      0.079455
# tariff_plans_22_1_min                         0.012306
# traffic_details_68_6_sum                      0.000030
# traffic_details_9_3d6_part                    0.002840
# spas_symptoms_agr_105_12_std                  0.000925
# traffic_details_37_3_std                      0.105454
# traffic_details_44_1_sum                      0.341473
# traffic_details_35_1d6_std                    0.027582
# traffic_details_5_1d3_part                    0.000122
# traffic_details_33_1d3_std                    0.021729
# traffic_details_2_6_cnt                       0.007437
# spas_symptoms_agr_150_6_std                   0.003925
# traffic_details_31_1_std                      0.432143
# traffic_details_53_1_sum                      0.408337
# traffic_details_65_3_sum                      0.058167
# traffic_details_38_3d6_avg                    0.015402
# traffic_details_18_1d6_avg                    0.051017
# target                                        0.000056
#
#                               traffic_details_39_3d6_std  \
# info_house_5_0_num                              0.027056
# area_0_0_num                                    0.003732
# user_lifetime_3_0_dt                            0.015377
# info_house_6_0_num                              0.073113
# traffic_details_43_1_std                        0.010201
# spas_symptoms_agr_154_12_sum                    0.062147
# traffic_details_62_1_sum                        0.008562
# traffic_details_39_3d6_std                      1.000000
# traffic_details_47_3_sum                        0.012079
# tariff_plans_22_1_min                           0.021190
# traffic_details_68_6_sum                        0.003275
# traffic_details_9_3d6_part                      0.322919
# spas_symptoms_agr_105_12_std                    0.014317
# traffic_details_37_3_std                        0.022444
# traffic_details_44_1_sum                        0.011958
# traffic_details_35_1d6_std                      0.452943
# traffic_details_5_1d3_part                      0.161980
# traffic_details_33_1d3_std                      0.085798
# traffic_details_2_6_cnt                         0.004489
# spas_symptoms_agr_150_6_std                     0.104662
# traffic_details_31_1_std                        0.016839
# traffic_details_53_1_sum                        0.003143
# traffic_details_65_3_sum                        0.003310
# traffic_details_38_3d6_avg                      0.755997
# traffic_details_18_1d6_avg                      0.257981
# target                                          0.000256
#
#                               traffic_details_47_3_sum  tariff_plans_22_1_min  \
# info_house_5_0_num                            0.005016               0.051886
# area_0_0_num                                  0.008863               0.047930
# user_lifetime_3_0_dt                          0.003746               0.102897
# info_house_6_0_num                            0.006387               0.104209
# traffic_details_43_1_std                      0.178213               0.011179
# spas_symptoms_agr_154_12_sum                  0.005199               0.134159
# traffic_details_62_1_sum                      0.079455               0.012306
# traffic_details_39_3d6_std                    0.012079               0.021190
# traffic_details_47_3_sum                      1.000000               0.040827
# tariff_plans_22_1_min                         0.040827               1.000000
# traffic_details_68_6_sum                      0.003030               0.002523
# traffic_details_9_3d6_part                    0.002425               0.012679
# spas_symptoms_agr_105_12_std                  0.008201               0.077981
# traffic_details_37_3_std                      0.309126               0.008880
# traffic_details_44_1_sum                      0.373980               0.050880
# traffic_details_35_1d6_std                    0.005690               0.017246
# traffic_details_5_1d3_part                    0.000706               0.001466
# traffic_details_33_1d3_std                    0.009862               0.011171
# traffic_details_2_6_cnt                       0.012595               0.075612
# spas_symptoms_agr_150_6_std                   0.011138               0.070810
# traffic_details_31_1_std                      0.062995               0.005876
# traffic_details_53_1_sum                      0.032540               0.011665
# traffic_details_65_3_sum                      0.064585               0.001117
# traffic_details_38_3d6_avg                    0.020117               0.017431
# traffic_details_18_1d6_avg                    0.003128               0.001798
# target                                        0.001561               0.013955
#
#                               ...  traffic_details_5_1d3_part  \
# info_house_5_0_num            ...                    0.001495
# area_0_0_num                  ...                    0.002155
# user_lifetime_3_0_dt          ...                    0.014301
# info_house_6_0_num            ...                    0.037656
# traffic_details_43_1_std      ...                    0.000133
# spas_symptoms_agr_154_12_sum  ...                    0.022517
# traffic_details_62_1_sum      ...                    0.000122
# traffic_details_39_3d6_std    ...                    0.161980
# traffic_details_47_3_sum      ...                    0.000706
# tariff_plans_22_1_min         ...                    0.001466
# traffic_details_68_6_sum      ...                    0.003150
# traffic_details_9_3d6_part    ...                    0.322475
# spas_symptoms_agr_105_12_std  ...                    0.003503
# traffic_details_37_3_std      ...                    0.000782
# traffic_details_44_1_sum      ...                    0.000054
# traffic_details_35_1d6_std    ...                    0.184384
# traffic_details_5_1d3_part    ...                    1.000000
# traffic_details_33_1d3_std    ...                    0.228071
# traffic_details_2_6_cnt       ...                    0.028633
# spas_symptoms_agr_150_6_std   ...                    0.046403
# traffic_details_31_1_std      ...                    0.001541
# traffic_details_53_1_sum      ...                    0.003969
# traffic_details_65_3_sum      ...                    0.000023
# traffic_details_38_3d6_avg    ...                    0.215597
# traffic_details_18_1d6_avg    ...                    0.483717
# target                        ...                    0.000067
#
#                               traffic_details_33_1d3_std  \
# info_house_5_0_num                              0.008226
# area_0_0_num                                    0.010953
# user_lifetime_3_0_dt                            0.019893
# info_house_6_0_num                              0.038740
# traffic_details_43_1_std                        0.024626
# spas_symptoms_agr_154_12_sum                    0.038810
# traffic_details_62_1_sum                        0.021729
# traffic_details_39_3d6_std                      0.085798
# traffic_details_47_3_sum                        0.009862
# tariff_plans_22_1_min                           0.011171
# traffic_details_68_6_sum                        0.002055
# traffic_details_9_3d6_part                      0.209257
# spas_symptoms_agr_105_12_std                    0.006330
# traffic_details_37_3_std                        0.016833
# traffic_details_44_1_sum                        0.023455
# traffic_details_35_1d6_std                      0.858799
# traffic_details_5_1d3_part                      0.228071
# traffic_details_33_1d3_std                      1.000000
# traffic_details_2_6_cnt                         0.014374
# spas_symptoms_agr_150_6_std                     0.059256
# traffic_details_31_1_std                        0.039878
# traffic_details_53_1_sum                        0.017519
# traffic_details_65_3_sum                        0.003705
# traffic_details_38_3d6_avg                      0.119894
# traffic_details_18_1d6_avg                      0.476962
# target                                          0.002548
#
#                               traffic_details_2_6_cnt  \
# info_house_5_0_num                           0.003615
# area_0_0_num                                 0.059998
# user_lifetime_3_0_dt                         0.166342
# info_house_6_0_num                           0.015759
# traffic_details_43_1_std                     0.002747
# spas_symptoms_agr_154_12_sum                 0.305884
# traffic_details_62_1_sum                     0.007437
# traffic_details_39_3d6_std                   0.004489
# traffic_details_47_3_sum                     0.012595
# tariff_plans_22_1_min                        0.075612
# traffic_details_68_6_sum                     0.000744
# traffic_details_9_3d6_part                   0.016687
# spas_symptoms_agr_105_12_std                 0.042353
# traffic_details_37_3_std                     0.005532
# traffic_details_44_1_sum                     0.009864
# traffic_details_35_1d6_std                   0.014720
# traffic_details_5_1d3_part                   0.028633
# traffic_details_33_1d3_std                   0.014374
# traffic_details_2_6_cnt                      1.000000
# spas_symptoms_agr_150_6_std                  0.035523
# traffic_details_31_1_std                     0.003101
# traffic_details_53_1_sum                     0.008104
# traffic_details_65_3_sum                     0.002338
# traffic_details_38_3d6_avg                   0.017931
# traffic_details_18_1d6_avg                   0.002690
# target                                       0.009780
#
#                               spas_symptoms_agr_150_6_std  \
# info_house_5_0_num                               0.066970
# area_0_0_num                                     0.027272
# user_lifetime_3_0_dt                             0.037267
# info_house_6_0_num                               0.444482
# traffic_details_43_1_std                         0.006879
# spas_symptoms_agr_154_12_sum                     0.429283
# traffic_details_62_1_sum                         0.003925
# traffic_details_39_3d6_std                       0.104662
# traffic_details_47_3_sum                         0.011138
# tariff_plans_22_1_min                            0.070810
# traffic_details_68_6_sum                         0.000945
# traffic_details_9_3d6_part                       0.106886
# spas_symptoms_agr_105_12_std                     0.019804
# traffic_details_37_3_std                         0.014616
# traffic_details_44_1_sum                         0.010820
# traffic_details_35_1d6_std                       0.065957
# traffic_details_5_1d3_part                       0.046403
# traffic_details_33_1d3_std                       0.059256
# traffic_details_2_6_cnt                          0.035523
# spas_symptoms_agr_150_6_std                      1.000000
# traffic_details_31_1_std                         0.013777
# traffic_details_53_1_sum                         0.006493
# traffic_details_65_3_sum                         0.000900
# traffic_details_38_3d6_avg                       0.123856
# traffic_details_18_1d6_avg                       0.030164
# target                                           0.000506
#
#                               traffic_details_31_1_std  \
# info_house_5_0_num                            0.001653
# area_0_0_num                                  0.001737
# user_lifetime_3_0_dt                          0.004374
# info_house_6_0_num                            0.004075
# traffic_details_43_1_std                      0.420218
# spas_symptoms_agr_154_12_sum                  0.013126
# traffic_details_62_1_sum                      0.432143
# traffic_details_39_3d6_std                    0.016839
# traffic_details_47_3_sum                      0.062995
# tariff_plans_22_1_min                         0.005876
# traffic_details_68_6_sum                      0.000012
# traffic_details_9_3d6_part                    0.008913
# spas_symptoms_agr_105_12_std                  0.002126
# traffic_details_37_3_std                      0.236209
# traffic_details_44_1_sum                      0.338008
# traffic_details_35_1d6_std                    0.050227
# traffic_details_5_1d3_part                    0.001541
# traffic_details_33_1d3_std                    0.039878
# traffic_details_2_6_cnt                       0.003101
# spas_symptoms_agr_150_6_std                   0.013777
# traffic_details_31_1_std                      1.000000
# traffic_details_53_1_sum                      0.692456
# traffic_details_65_3_sum                      0.016276
# traffic_details_38_3d6_avg                    0.026555
# traffic_details_18_1d6_avg                    0.087179
# target                                        0.000555
#
#                               traffic_details_53_1_sum  \
# info_house_5_0_num                            0.003572
# area_0_0_num                                  0.003590
# user_lifetime_3_0_dt                          0.005686
# info_house_6_0_num                            0.007471
# traffic_details_43_1_std                      0.182965
# spas_symptoms_agr_154_12_sum                  0.001869
# traffic_details_62_1_sum                      0.408337
# traffic_details_39_3d6_std                    0.003143
# traffic_details_47_3_sum                      0.032540
# tariff_plans_22_1_min                         0.011665
# traffic_details_68_6_sum                      0.000044
# traffic_details_9_3d6_part                    0.000034
# spas_symptoms_agr_105_12_std                  0.003187
# traffic_details_37_3_std                      0.169030
# traffic_details_44_1_sum                      0.152516
# traffic_details_35_1d6_std                    0.024053
# traffic_details_5_1d3_part                    0.003969
# traffic_details_33_1d3_std                    0.017519
# traffic_details_2_6_cnt                       0.008104
# spas_symptoms_agr_150_6_std                   0.006493
# traffic_details_31_1_std                      0.692456
# traffic_details_53_1_sum                      1.000000
# traffic_details_65_3_sum                      0.015680
# traffic_details_38_3d6_avg                    0.008081
# traffic_details_18_1d6_avg                    0.056380
# target                                        0.000287
#
#                               traffic_details_65_3_sum  \
# info_house_5_0_num                            0.001154
# area_0_0_num                                  0.007523
# user_lifetime_3_0_dt                          0.000686
# info_house_6_0_num                            0.000328
# traffic_details_43_1_std                      0.015042
# spas_symptoms_agr_154_12_sum                  0.000133
# traffic_details_62_1_sum                      0.058167
# traffic_details_39_3d6_std                    0.003310
# traffic_details_47_3_sum                      0.064585
# tariff_plans_22_1_min                         0.001117
# traffic_details_68_6_sum                      0.001327
# traffic_details_9_3d6_part                    0.000327
# spas_symptoms_agr_105_12_std                  0.000040
# traffic_details_37_3_std                      0.252633
# traffic_details_44_1_sum                      0.016149
# traffic_details_35_1d6_std                    0.002706
# traffic_details_5_1d3_part                    0.000023
# traffic_details_33_1d3_std                    0.003705
# traffic_details_2_6_cnt                       0.002338
# spas_symptoms_agr_150_6_std                   0.000900
# traffic_details_31_1_std                      0.016276
# traffic_details_53_1_sum                      0.015680
# traffic_details_65_3_sum                      1.000000
# traffic_details_38_3d6_avg                    0.006537
# traffic_details_18_1d6_avg                    0.001605
# target                                        0.000145
#
#                               traffic_details_38_3d6_avg  \
# info_house_5_0_num                              0.019423
# area_0_0_num                                    0.000802
# user_lifetime_3_0_dt                            0.023168
# info_house_6_0_num                              0.075429
# traffic_details_43_1_std                        0.015148
# spas_symptoms_agr_154_12_sum                    0.050611
# traffic_details_62_1_sum                        0.015402
# traffic_details_39_3d6_std                      0.755997
# traffic_details_47_3_sum                        0.020117
# tariff_plans_22_1_min                           0.017431
# traffic_details_68_6_sum                        0.004072
# traffic_details_9_3d6_part                      0.407316
# spas_symptoms_agr_105_12_std                    0.004696
# traffic_details_37_3_std                        0.039840
# traffic_details_44_1_sum                        0.017437
# traffic_details_35_1d6_std                      0.349982
# traffic_details_5_1d3_part                      0.215597
# traffic_details_33_1d3_std                      0.119894
# traffic_details_2_6_cnt                         0.017931
# spas_symptoms_agr_150_6_std                     0.123856
# traffic_details_31_1_std                        0.026555
# traffic_details_53_1_sum                        0.008081
# traffic_details_65_3_sum                        0.006537
# traffic_details_38_3d6_avg                      1.000000
# traffic_details_18_1d6_avg                      0.343370
# target                                          0.001037
#
#                               traffic_details_18_1d6_avg    target
# info_house_5_0_num                              0.030499  0.003528
# area_0_0_num                                    0.003470  0.002379
# user_lifetime_3_0_dt                            0.003332  0.005310
# info_house_6_0_num                              0.032545  0.006218
# traffic_details_43_1_std                        0.048431  0.000607
# spas_symptoms_agr_154_12_sum                    0.009300  0.012160
# traffic_details_62_1_sum                        0.051017  0.000056
# traffic_details_39_3d6_std                      0.257981  0.000256
# traffic_details_47_3_sum                        0.003128  0.001561
# tariff_plans_22_1_min                           0.001798  0.013955
# traffic_details_68_6_sum                        0.001651  0.013640
# traffic_details_9_3d6_part                      0.283577  0.000421
# spas_symptoms_agr_105_12_std                    0.003161  0.029562
# traffic_details_37_3_std                        0.001665  0.000767
# traffic_details_44_1_sum                        0.042585  0.001838
# traffic_details_35_1d6_std                      0.565038  0.001077
# traffic_details_5_1d3_part                      0.483717  0.000067
# traffic_details_33_1d3_std                      0.476962  0.002548
# traffic_details_2_6_cnt                         0.002690  0.009780
# spas_symptoms_agr_150_6_std                     0.030164  0.000506
# traffic_details_31_1_std                        0.087179  0.000555
# traffic_details_53_1_sum                        0.056380  0.000287
# traffic_details_65_3_sum                        0.001605  0.000145
# traffic_details_38_3d6_avg                      0.343370  0.001037
# traffic_details_18_1d6_avg                      1.000000  0.001219
# target                                          0.001219  1.000000
#
# [26 rows x 26 columns]

# %%
dataset_for_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702086 entries, 0 to 702085
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   info_house_5_0_num            696471 non-null  float64
#  1   area_0_0_num                  467367 non-null  float64
#  2   user_lifetime_3_0_dt          696827 non-null  float64
#  3   info_house_6_0_num            696471 non-null  float64
#  4   traffic_details_43_1_std      686189 non-null  float64
#  5   spas_symptoms_agr_154_12_sum  692032 non-null  float64
#  6   traffic_details_62_1_sum      686189 non-null  float64
#  7   traffic_details_39_3d6_std    686189 non-null  float64
#  8   traffic_details_47_3_sum      686189 non-null  float64
#  9   tariff_plans_22_1_min         697313 non-null  float64
#  10  traffic_details_68_6_sum      686189 non-null  float64
#  11  traffic_details_9_3d6_part    686189 non-null  float64
#  12  spas_symptoms_agr_105_12_std  691863 non-null  float64
#  13  traffic_details_37_3_std      686189 non-null  float64
#  14  traffic_details_44_1_sum      686189 non-null  float64
#  15  traffic_details_35_1d6_std    686189 non-null  float64
#  16  traffic_details_5_1d3_part    686189 non-null  float64
#  17  traffic_details_33_1d3_std    686189 non-null  float64
#  18  traffic_details_2_6_cnt       686189 non-null  float64
#  19  spas_symptoms_agr_150_6_std   691863 non-null  float64
#  20  traffic_details_31_1_std      686189 non-null  float64
#  21  traffic_details_53_1_sum      686189 non-null  float64
#  22  traffic_details_65_3_sum      686189 non-null  float64
#  23  traffic_details_38_3d6_avg    686189 non-null  float64
#  24  traffic_details_18_1d6_avg    686189 non-null  float64
#  25  target                        702086 non-null  int32
# dtypes: float64(25), int32(1)
# memory usage: 136.6 MB
